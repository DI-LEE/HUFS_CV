# %%
import tensorflow as tf
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Load Data

# %%
def loadData():
    data = io.loadmat("face_landmark.mat")
    images = data["images"]
    landmarks = data["landmarks"]
    print("im_shape:", images.shape)
    print("landmarks_shape:", landmarks.shape)

    return images, landmarks

# %%
images, landmarks = loadData()
# Out:
# im_shape: (2140, 96, 96)
# landmarks_shape: (2140, 15, 2)

# %% [markdown]
# # Visualize Data

# %%
def visualize_data(images, landmarks, num_images):
    fig = plt.figure(figsize=(10,10))
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

    for i in range(num_images):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        ax.imshow(images[i], cmap='gray')
        for (x, y) in landmarks[i].reshape(-1, 2):
            # Plot keypoints/landmarks on the image
            ax.scatter(x, y, marker='o', s=10, color='r')

    plt.show()

# %%
visualize_data(images, landmarks, num_images=16)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### split

# %%
def split_data(data, size):
    np.random.seed(2023)
    
    idx = np.random.permutation(size)

    train_size = int(size * 0.6)
    val_size = int(size * 0.2)
    test_size = int(size * 0.2)

    train_ds = data[idx[: train_size]]
    val_ds = data[idx[train_size: train_size + val_size]]
    test_ds = data[idx[size - test_size:]]

    return train_ds, val_ds, test_ds

# %%
train_img, val_img, test_img = split_data(images, images.shape[0])

# %%
train_lmrk, val_lmrk, test_lmrk = split_data(landmarks, landmarks.shape[0])

# %% [markdown]
# ### Reshape

# %%
print(train_img.shape)
print(train_lmrk.shape)
# Out:
# (1284, 96, 96)
# (1284, 15, 2)

# %%
print(val_img.shape)
print(val_lmrk.shape)
# Out:
# (428, 96, 96)
# (428, 15, 2)

# %%
print(test_img.shape)
print(test_lmrk.shape)
# Out:
# (428, 96, 96)
# (428, 15, 2)

# %%
train_lmrk = train_lmrk.reshape((1284, -1))
val_lmrk = val_lmrk.reshape((428, -1))
test_lmrk = test_lmrk.reshape((428, -1))

# %%
print(train_lmrk.shape)
print(val_lmrk.shape)
print(test_lmrk.shape)
# Out:
# (1284, 30)
# (428, 30)
# (428, 30)

# %% [markdown]
# # Model
# * Output은 15개의 얼굴 랜드마크에 해당하는 x, y 좌표이므로 총 30개의 출력 유닛이 필요

# %%
from tensorflow.keras import regularizers

# Define the input shape
input_layer = tf.keras.Input(shape=(96, 96, 1))

# Define the convolution and pooling layers
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_regularizer=regularizers.l1(0.01))(input_layer)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_regularizer=regularizers.l1(0.01))(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l1(0.01))(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=regularizers.l1(0.01))(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the tensor output for the Fully Connected layer
x = tf.keras.layers.Flatten()(x)

# Define the fully connected layer
x = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l1(0.01))(x)

# Define the output layer (30 units for 15 landmarks x and y coordinates)
output_layer = tf.keras.layers.Dense(30)(x)

# Create the model
model = tf.keras.Model(input_layer, output_layer)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d (Conv2D)             (None, 94, 94, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 47, 47, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 45, 45, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 30)                1950
#
# =================================================================
# Total params: 132,542
# Trainable params: 132,542
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Predict

# %%
@tf.function
def predict(x):
    return model(x, training=False)

# %% [markdown]
# # Optimization

# %%
@tf.function
def optimize(x,y_true,loss_function):
    with tf.GradientTape() as tape:
        y_pred = predict(x)
        loss = loss_function(y_pred, y_true)
    grads = tape.gradient(loss, model.trainable_variables)
    opt.apply_gradients(zip(grads, model.trainable_variables))
    return loss

# %%
opt = tf.keras.optimizers.Adam(learning_rate=1e-3)

# %% [markdown]
# # Loss
# * 실제 레이블(y_true)와 모델의 예측 결과(y)를 입력

# %%
@tf.function
def l1_loss(y_pred, y_true):
    return tf.reduce_mean(tf.abs(y_true - y_pred))

@tf.function
def l2_loss(y_pred, y_true):
    return tf.reduce_mean(tf.square(y_true - y_pred))

@tf.function
def cosine_loss(y_pred, y_true):
    # Normalize each vector
    y_true_normalized = tf.nn.l2_normalize(y_true, axis=-1)
    y_pred_normalized = tf.nn.l2_normalize(y_pred, axis=-1)
    # Compute the dot product (cosine similarity)
    dot_product = tf.reduce_sum(y_true_normalized * y_pred_normalized, axis=-1)
    # Subtract the dot product from 1 to get the loss
    return 1 - tf.reduce_mean(dot_product)

# %%
def combine_l2_cosine_loss(y_pred, y_true, lamda=1.0):
    return l2_loss(y_pred, y_true) + lamda*cosine_loss(y_pred, y_true)

# %% [markdown]
# # Train & Evaluation

# %%
""" start training """
loss_function = combine_l2_cosine_loss

max_epochs = 1000
batch_size = 32


loss_history = []
val_loss_best = np.inf
train_size = int(images.shape[0] * 0.6)

#Early stopping hyperparameter
patience = 50  # number of epochs to wait before stopping if there is no improvement
wait = 0  # counter for epochs without improvement


for epoch in range(max_epochs):
    # get a minibatch
    idx = np.random.permutation(train_size)
    batch_idx = idx[:batch_size]

    # optimize
    train_loss = optimize(train_img[batch_idx], train_lmrk[batch_idx], loss_function)
    train_loss = train_loss.numpy()

    # evaluate on val_set
    y = predict(val_img)
    val_loss = loss_function(y, val_lmrk).numpy()

    # Early stopping check
    if val_loss < val_loss_best:
        val_loss_best = val_loss
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            print(f'Early stopping on epoch {epoch}')
            break
        
    print('Epoch:', epoch, '. Training Loss:', train_loss, ' Validation Loss:', val_loss, ' Best Validation Loss:', val_loss_best)
    loss_history.append([train_loss, val_loss])
# Out:
# Epoch: 0 . Training Loss: 2504.9065  Validation Loss: 1812.4226  Best Validation Loss: 1812.4226
# Epoch: 1 . Training Loss: 1822.1272  Validation Loss: 1440.3347  Best Validation Loss: 1440.3347
# Epoch: 2 . Training Loss: 1452.7178  Validation Loss: 1297.8176  Best Validation Loss: 1297.8176
# Epoch: 3 . Training Loss: 1359.8872  Validation Loss: 1083.5515  Best Validation Loss: 1083.5515
# Epoch: 4 . Training Loss: 1056.678  Validation Loss: 977.4999  Best Validation Loss: 977.4999
# Epoch: 5 . Training Loss: 992.7655  Validation Loss: 920.6145  Best Validation Loss: 920.6145
# Epoch: 6 . Training Loss: 931.50446  Validation Loss: 828.95496  Best Validation Loss: 828.95496
# Epoch: 7 . Training Loss: 798.347  Validation Loss: 726.1148  Best Validation Loss: 726.1148
# Epoch: 8 . Training Loss: 735.9108  Validation Loss: 661.41235  Best Validation Loss: 661.41235
# Epoch: 9 . Training Loss: 654.3918  Validation Loss: 596.57043  Best Validation Loss: 596.57043
# Epoch: 10 . Training Loss: 589.3796  Validation Loss: 505.1327  Best Validation Loss: 505.1327
# Epoch: 11 . Training Loss: 483.5213  Validation Loss: 456.95496  Best Validation Loss: 456.95496
# Epoch: 12 . Training Loss: 449.86533  Validation Loss: 428.67978  Best Validation Loss: 428.67978
# Epoch: 13 . Training Loss: 434.99167  Validation Loss: 385.02805  Best Validation Loss: 385.02805
# Epoch: 14 . Training Loss: 344.72827  Validation Loss: 336.499  Best Validation Loss: 336.499
# Epoch: 15 . Training Loss: 318.6463  Validation Loss: 303.83963  Best Validation Loss: 303.83963
# Epoch: 16 . Training Loss: 300.6626  Validation Loss: 303.79562  Best Validation Loss: 303.79562
# Epoch: 17 . Training Loss: 351.9733  Validation Loss: 280.73376  Best Validation Loss: 280.73376
# Epoch: 18 . Training Loss: 273.3569  Validation Loss: 242.52345  Best Validation Loss: 242.52345
# Epoch: 19 . Training Loss: 242.55318  Validation Loss: 235.91057  Best Validation Loss: 235.91057
# Epoch: 20 . Training Loss: 206.13898  Validation Loss: 233.00325  Best Validation Loss: 233.00325
# Epoch: 21 . Training Loss: 218.70673  Validation Loss: 208.91437  Best Validation Loss: 208.91437
# Epoch: 22 . Training Loss: 198.32375  Validation Loss: 187.00612  Best Validation Loss: 187.00612
# Epoch: 23 . Training Loss: 170.04118  Validation Loss: 179.66086  Best Validation Loss: 179.66086
# Epoch: 24 . Training Loss: 171.31111  Validation Loss: 180.50453  Best Validation Loss: 179.66086
# Epoch: 25 . Training Loss: 160.27144  Validation Loss: 181.62798  Best Validation Loss: 179.66086
# Epoch: 26 . Training Loss: 223.6473  Validation Loss: 156.2416  Best Validation Loss: 156.2416
# Epoch: 27 . Training Loss: 170.98953  Validation Loss: 173.70293  Best Validation Loss: 156.2416
# Epoch: 28 . Training Loss: 182.95474  Validation Loss: 181.00868  Best Validation Loss: 156.2416
# Epoch: 29 . Training Loss: 177.49086  Validation Loss: 166.86427  Best Validation Loss: 156.2416
# Epoch: 30 . Training Loss: 160.82104  Validation Loss: 145.70638  Best Validation Loss: 145.70638
# Epoch: 31 . Training Loss: 148.36118  Validation Loss: 150.92534  Best Validation Loss: 145.70638
# Epoch: 32 . Training Loss: 132.24863  Validation Loss: 173.35094  Best Validation Loss: 145.70638
# Epoch: 33 . Training Loss: 169.56377  Validation Loss: 165.09567  Best Validation Loss: 145.70638
# Epoch: 34 . Training Loss: 132.57349  Validation Loss: 142.2443  Best Validation Loss: 142.2443
# Epoch: 35 . Training Loss: 140.19745  Validation Loss: 171.34166  Best Validation Loss: 142.2443
# Epoch: 36 . Training Loss: 135.95593  Validation Loss: 205.90482  Best Validation Loss: 142.2443
# Epoch: 37 . Training Loss: 223.4178  Validation Loss: 198.24258  Best Validation Loss: 142.2443
# Epoch: 38 . Training Loss: 222.02202  Validation Loss: 158.25163  Best Validation Loss: 142.2443
# Epoch: 39 . Training Loss: 210.54784  Validation Loss: 141.27667  Best Validation Loss: 141.27667
# Epoch: 40 . Training Loss: 119.467926  Validation Loss: 159.62804  Best Validation Loss: 141.27667
# Epoch: 41 . Training Loss: 133.39255  Validation Loss: 178.93617  Best Validation Loss: 141.27667
# Epoch: 42 . Training Loss: 139.77373  Validation Loss: 159.05588  Best Validation Loss: 141.27667
# Epoch: 43 . Training Loss: 167.90564  Validation Loss: 139.69284  Best Validation Loss: 139.69284
# Epoch: 44 . Training Loss: 138.1576  Validation Loss: 145.23111  Best Validation Loss: 139.69284
# Epoch: 45 . Training Loss: 124.28188  Validation Loss: 164.05832  Best Validation Loss: 139.69284
# Epoch: 46 . Training Loss: 190.62279  Validation Loss: 161.60141  Best Validation Loss: 139.69284
# Epoch: 47 . Training Loss: 171.9792  Validation Loss: 148.32552  Best Validation Loss: 139.69284
# Epoch: 48 . Training Loss: 115.48101  Validation Loss: 137.20561  Best Validation Loss: 137.20561
# Epoch: 49 . Training Loss: 141.96579  Validation Loss: 138.78693  Best Validation Loss: 137.20561
# Epoch: 50 . Training Loss: 123.22548  Validation Loss: 139.89882  Best Validation Loss: 137.20561
# Epoch: 51 . Training Loss: 143.43253  Validation Loss: 133.06432  Best Validation Loss: 133.06432
# Epoch: 52 . Training Loss: 123.55407  Validation Loss: 134.89  Best Validation Loss: 133.06432
# Epoch: 53 . Training Loss: 131.57307  Validation Loss: 139.18233  Best Validation Loss: 133.06432
# Epoch: 54 . Training Loss: 121.27327  Validation Loss: 135.57246  Best Validation Loss: 133.06432
# Epoch: 55 . Training Loss: 101.25768  Validation Loss: 133.65573  Best Validation Loss: 133.06432
# Epoch: 56 . Training Loss: 153.0444  Validation Loss: 134.53922  Best Validation Loss: 133.06432
# Epoch: 57 . Training Loss: 158.15482  Validation Loss: 128.67099  Best Validation Loss: 128.67099
# Epoch: 58 . Training Loss: 141.99115  Validation Loss: 127.123726  Best Validation Loss: 127.123726
# Epoch: 59 . Training Loss: 125.36927  Validation Loss: 127.21424  Best Validation Loss: 127.123726
# Epoch: 60 . Training Loss: 93.552284  Validation Loss: 128.65373  Best Validation Loss: 127.123726
# Epoch: 61 . Training Loss: 125.986336  Validation Loss: 131.08635  Best Validation Loss: 127.123726
# Epoch: 62 . Training Loss: 191.21909  Validation Loss: 126.075356  Best Validation Loss: 126.075356
# Epoch: 63 . Training Loss: 128.88998  Validation Loss: 130.01254  Best Validation Loss: 126.075356
# Epoch: 64 . Training Loss: 102.85456  Validation Loss: 135.76924  Best Validation Loss: 126.075356
# Epoch: 65 . Training Loss: 138.05605  Validation Loss: 124.74664  Best Validation Loss: 124.74664
# Epoch: 66 . Training Loss: 92.2712  Validation Loss: 127.89232  Best Validation Loss: 124.74664
# Epoch: 67 . Training Loss: 138.56491  Validation Loss: 127.21697  Best Validation Loss: 124.74664
# Epoch: 68 . Training Loss: 107.89835  Validation Loss: 122.88035  Best Validation Loss: 122.88035
# Epoch: 69 . Training Loss: 134.89804  Validation Loss: 123.29999  Best Validation Loss: 122.88035
# Epoch: 70 . Training Loss: 128.0866  Validation Loss: 123.52046  Best Validation Loss: 122.88035
# Epoch: 71 . Training Loss: 143.10765  Validation Loss: 122.49259  Best Validation Loss: 122.49259
# Epoch: 72 . Training Loss: 118.11641  Validation Loss: 122.39622  Best Validation Loss: 122.39622
# Epoch: 73 . Training Loss: 121.84019  Validation Loss: 120.99342  Best Validation Loss: 120.99342
# Epoch: 74 . Training Loss: 80.80131  Validation Loss: 121.636246  Best Validation Loss: 120.99342
# Epoch: 75 . Training Loss: 142.34737  Validation Loss: 120.407524  Best Validation Loss: 120.407524
# Epoch: 76 . Training Loss: 104.774345  Validation Loss: 119.8061  Best Validation Loss: 119.8061
# Epoch: 77 . Training Loss: 136.58287  Validation Loss: 119.87478  Best Validation Loss: 119.8061
# Epoch: 78 . Training Loss: 103.28811  Validation Loss: 119.51996  Best Validation Loss: 119.51996
# Epoch: 79 . Training Loss: 106.40841  Validation Loss: 118.86285  Best Validation Loss: 118.86285
# Epoch: 80 . Training Loss: 121.687706  Validation Loss: 118.84737  Best Validation Loss: 118.84737
# Epoch: 81 . Training Loss: 132.3555  Validation Loss: 118.09659  Best Validation Loss: 118.09659
# Epoch: 82 . Training Loss: 96.3575  Validation Loss: 119.65015  Best Validation Loss: 118.09659
# Epoch: 83 . Training Loss: 70.43688  Validation Loss: 127.00832  Best Validation Loss: 118.09659
# Epoch: 84 . Training Loss: 108.01226  Validation Loss: 123.136536  Best Validation Loss: 118.09659
# Epoch: 85 . Training Loss: 109.80715  Validation Loss: 116.68309  Best Validation Loss: 116.68309
# Epoch: 86 . Training Loss: 91.8879  Validation Loss: 125.67488  Best Validation Loss: 116.68309
# Epoch: 87 . Training Loss: 124.81809  Validation Loss: 116.576355  Best Validation Loss: 116.576355
# Epoch: 88 . Training Loss: 157.75836  Validation Loss: 134.19547  Best Validation Loss: 116.576355
# Epoch: 89 . Training Loss: 119.847694  Validation Loss: 141.36545  Best Validation Loss: 116.576355
# Epoch: 90 . Training Loss: 92.2476  Validation Loss: 121.65095  Best Validation Loss: 116.576355
# Epoch: 91 . Training Loss: 155.43698  Validation Loss: 130.59344  Best Validation Loss: 116.576355
# Epoch: 92 . Training Loss: 133.84027  Validation Loss: 159.9031  Best Validation Loss: 116.576355
# Epoch: 93 . Training Loss: 210.1935  Validation Loss: 117.230484  Best Validation Loss: 116.576355
# Epoch: 94 . Training Loss: 92.268425  Validation Loss: 119.39604  Best Validation Loss: 116.576355
# Epoch: 95 . Training Loss: 89.92602  Validation Loss: 142.3595  Best Validation Loss: 116.576355
# Epoch: 96 . Training Loss: 137.00975  Validation Loss: 137.18016  Best Validation Loss: 116.576355
# Epoch: 97 . Training Loss: 131.61343  Validation Loss: 113.39444  Best Validation Loss: 113.39444
# Epoch: 98 . Training Loss: 116.70054  Validation Loss: 132.6203  Best Validation Loss: 113.39444
# Epoch: 99 . Training Loss: 120.99009  Validation Loss: 124.72398  Best Validation Loss: 113.39444
# Epoch: 100 . Training Loss: 116.26372  Validation Loss: 114.16982  Best Validation Loss: 113.39444
# Epoch: 101 . Training Loss: 99.22819  Validation Loss: 112.349174  Best Validation Loss: 112.349174
# Epoch: 102 . Training Loss: 95.728676  Validation Loss: 115.23642  Best Validation Loss: 112.349174
# Epoch: 103 . Training Loss: 92.32314  Validation Loss: 118.40876  Best Validation Loss: 112.349174
# Epoch: 104 . Training Loss: 76.70848  Validation Loss: 116.30911  Best Validation Loss: 112.349174
# Epoch: 105 . Training Loss: 107.543625  Validation Loss: 112.39818  Best Validation Loss: 112.349174
# Epoch: 106 . Training Loss: 122.20128  Validation Loss: 119.036095  Best Validation Loss: 112.349174
# Epoch: 107 . Training Loss: 98.5653  Validation Loss: 124.29548  Best Validation Loss: 112.349174
# Epoch: 108 . Training Loss: 123.4074  Validation Loss: 112.08951  Best Validation Loss: 112.08951
# Epoch: 109 . Training Loss: 123.02412  Validation Loss: 112.9977  Best Validation Loss: 112.08951
# Epoch: 110 . Training Loss: 86.5337  Validation Loss: 115.626686  Best Validation Loss: 112.08951
# Epoch: 111 . Training Loss: 140.77391  Validation Loss: 113.4266  Best Validation Loss: 112.08951
# Epoch: 112 . Training Loss: 124.35306  Validation Loss: 110.647224  Best Validation Loss: 110.647224
# Epoch: 113 . Training Loss: 96.76499  Validation Loss: 112.966255  Best Validation Loss: 110.647224
# Epoch: 114 . Training Loss: 84.84073  Validation Loss: 119.61132  Best Validation Loss: 110.647224
# Epoch: 115 . Training Loss: 118.43165  Validation Loss: 111.58346  Best Validation Loss: 110.647224
# Epoch: 116 . Training Loss: 76.19569  Validation Loss: 115.615265  Best Validation Loss: 110.647224
# Epoch: 117 . Training Loss: 138.00624  Validation Loss: 128.0104  Best Validation Loss: 110.647224
# Epoch: 118 . Training Loss: 107.31336  Validation Loss: 119.79375  Best Validation Loss: 110.647224
# Epoch: 119 . Training Loss: 120.529465  Validation Loss: 108.82334  Best Validation Loss: 108.82334
# Epoch: 120 . Training Loss: 98.40926  Validation Loss: 116.80917  Best Validation Loss: 108.82334
# Epoch: 121 . Training Loss: 87.713036  Validation Loss: 125.57907  Best Validation Loss: 108.82334
# Epoch: 122 . Training Loss: 169.8655  Validation Loss: 111.752686  Best Validation Loss: 108.82334
# Epoch: 123 . Training Loss: 120.55771  Validation Loss: 109.76674  Best Validation Loss: 108.82334
# Epoch: 124 . Training Loss: 70.65453  Validation Loss: 111.989685  Best Validation Loss: 108.82334
# Epoch: 125 . Training Loss: 97.29055  Validation Loss: 107.157745  Best Validation Loss: 107.157745
# Epoch: 126 . Training Loss: 95.705864  Validation Loss: 118.52564  Best Validation Loss: 107.157745
# Epoch: 127 . Training Loss: 93.77317  Validation Loss: 132.80925  Best Validation Loss: 107.157745
# Epoch: 128 . Training Loss: 107.007835  Validation Loss: 124.9256  Best Validation Loss: 107.157745
# Epoch: 129 . Training Loss: 97.274605  Validation Loss: 107.05961  Best Validation Loss: 107.05961
# Epoch: 130 . Training Loss: 76.9291  Validation Loss: 115.988914  Best Validation Loss: 107.05961
# Epoch: 131 . Training Loss: 143.41315  Validation Loss: 121.12359  Best Validation Loss: 107.05961
# Epoch: 132 . Training Loss: 106.31352  Validation Loss: 107.982155  Best Validation Loss: 107.05961
# Epoch: 133 . Training Loss: 112.44453  Validation Loss: 114.33895  Best Validation Loss: 107.05961
# Epoch: 134 . Training Loss: 128.9689  Validation Loss: 124.90936  Best Validation Loss: 107.05961
# Epoch: 135 . Training Loss: 82.17039  Validation Loss: 124.65672  Best Validation Loss: 107.05961
# Epoch: 136 . Training Loss: 119.57275  Validation Loss: 107.02266  Best Validation Loss: 107.02266
# Epoch: 137 . Training Loss: 121.87804  Validation Loss: 111.35513  Best Validation Loss: 107.02266
# Epoch: 138 . Training Loss: 71.241936  Validation Loss: 137.03615  Best Validation Loss: 107.02266
# Epoch: 139 . Training Loss: 115.15106  Validation Loss: 108.890335  Best Validation Loss: 107.02266
# Epoch: 140 . Training Loss: 119.22367  Validation Loss: 106.10561  Best Validation Loss: 106.10561
# Epoch: 141 . Training Loss: 118.85857  Validation Loss: 120.989525  Best Validation Loss: 106.10561
# Epoch: 142 . Training Loss: 137.65776  Validation Loss: 128.15868  Best Validation Loss: 106.10561
# Epoch: 143 . Training Loss: 202.25317  Validation Loss: 104.14709  Best Validation Loss: 104.14709
# Epoch: 144 . Training Loss: 80.41337  Validation Loss: 128.49763  Best Validation Loss: 104.14709
# Epoch: 145 . Training Loss: 136.36787  Validation Loss: 119.667534  Best Validation Loss: 104.14709
# Epoch: 146 . Training Loss: 108.984955  Validation Loss: 102.84644  Best Validation Loss: 102.84644
# Epoch: 147 . Training Loss: 86.06984  Validation Loss: 112.06217  Best Validation Loss: 102.84644
# Epoch: 148 . Training Loss: 97.109276  Validation Loss: 110.873405  Best Validation Loss: 102.84644
# Epoch: 149 . Training Loss: 70.84496  Validation Loss: 106.242256  Best Validation Loss: 102.84644
# Epoch: 150 . Training Loss: 121.70392  Validation Loss: 103.26797  Best Validation Loss: 102.84644
# Epoch: 151 . Training Loss: 79.26724  Validation Loss: 105.19257  Best Validation Loss: 102.84644
# Epoch: 152 . Training Loss: 80.989136  Validation Loss: 102.52051  Best Validation Loss: 102.52051
# Epoch: 153 . Training Loss: 112.51591  Validation Loss: 112.86061  Best Validation Loss: 102.52051
# Epoch: 154 . Training Loss: 122.322296  Validation Loss: 116.91386  Best Validation Loss: 102.52051
# Epoch: 155 . Training Loss: 122.6519  Validation Loss: 102.392746  Best Validation Loss: 102.392746
# Epoch: 156 . Training Loss: 74.591675  Validation Loss: 102.866684  Best Validation Loss: 102.392746
# Epoch: 157 . Training Loss: 85.66451  Validation Loss: 108.41553  Best Validation Loss: 102.392746
# Epoch: 158 . Training Loss: 132.92976  Validation Loss: 105.430405  Best Validation Loss: 102.392746
# Epoch: 159 . Training Loss: 86.87915  Validation Loss: 100.8087  Best Validation Loss: 100.8087
# Epoch: 160 . Training Loss: 78.14336  Validation Loss: 100.55042  Best Validation Loss: 100.55042
# Epoch: 161 . Training Loss: 88.3154  Validation Loss: 102.898056  Best Validation Loss: 100.55042
# Epoch: 162 . Training Loss: 96.56484  Validation Loss: 102.295074  Best Validation Loss: 100.55042
# Epoch: 163 . Training Loss: 109.76855  Validation Loss: 104.56281  Best Validation Loss: 100.55042
# Epoch: 164 . Training Loss: 122.76889  Validation Loss: 99.57658  Best Validation Loss: 99.57658
# Epoch: 165 . Training Loss: 90.48625  Validation Loss: 102.58965  Best Validation Loss: 99.57658
# Epoch: 166 . Training Loss: 107.60868  Validation Loss: 121.16401  Best Validation Loss: 99.57658
# Epoch: 167 . Training Loss: 94.270256  Validation Loss: 113.252945  Best Validation Loss: 99.57658
# Epoch: 168 . Training Loss: 113.299706  Validation Loss: 98.34483  Best Validation Loss: 98.34483
# Epoch: 169 . Training Loss: 103.601715  Validation Loss: 103.49678  Best Validation Loss: 98.34483
# Epoch: 170 . Training Loss: 73.54131  Validation Loss: 105.585556  Best Validation Loss: 98.34483
# Epoch: 171 . Training Loss: 76.9968  Validation Loss: 102.22612  Best Validation Loss: 98.34483
# Epoch: 172 . Training Loss: 88.49131  Validation Loss: 99.84359  Best Validation Loss: 98.34483
# Epoch: 173 . Training Loss: 88.756165  Validation Loss: 97.327705  Best Validation Loss: 97.327705
# Epoch: 174 . Training Loss: 79.71121  Validation Loss: 97.90275  Best Validation Loss: 97.327705
# Epoch: 175 . Training Loss: 64.75787  Validation Loss: 97.20105  Best Validation Loss: 97.20105
# Epoch: 176 . Training Loss: 97.672356  Validation Loss: 97.06165  Best Validation Loss: 97.06165
# Epoch: 177 . Training Loss: 101.3337  Validation Loss: 99.35612  Best Validation Loss: 97.06165
# Epoch: 178 . Training Loss: 95.23  Validation Loss: 97.03993  Best Validation Loss: 97.03993
# Epoch: 179 . Training Loss: 69.86609  Validation Loss: 100.60142  Best Validation Loss: 97.03993
# Epoch: 180 . Training Loss: 67.066505  Validation Loss: 98.28472  Best Validation Loss: 97.03993
# Epoch: 181 . Training Loss: 97.63756  Validation Loss: 98.551636  Best Validation Loss: 97.03993
# Epoch: 182 . Training Loss: 89.4169  Validation Loss: 124.98169  Best Validation Loss: 97.03993
# Epoch: 183 . Training Loss: 119.91248  Validation Loss: 111.69586  Best Validation Loss: 97.03993
# Epoch: 184 . Training Loss: 83.30534  Validation Loss: 94.80265  Best Validation Loss: 94.80265
# Epoch: 185 . Training Loss: 85.5392  Validation Loss: 102.45516  Best Validation Loss: 94.80265
# Epoch: 186 . Training Loss: 73.190216  Validation Loss: 105.18682  Best Validation Loss: 94.80265
# Epoch: 187 . Training Loss: 95.201935  Validation Loss: 94.60695  Best Validation Loss: 94.60695
# Epoch: 188 . Training Loss: 89.71027  Validation Loss: 100.31557  Best Validation Loss: 94.60695
# Epoch: 189 . Training Loss: 106.83201  Validation Loss: 94.090836  Best Validation Loss: 94.090836
# Epoch: 190 . Training Loss: 90.091805  Validation Loss: 99.047966  Best Validation Loss: 94.090836
# Epoch: 191 . Training Loss: 83.7559  Validation Loss: 106.14328  Best Validation Loss: 94.090836
# Epoch: 192 . Training Loss: 79.113464  Validation Loss: 100.242645  Best Validation Loss: 94.090836
# Epoch: 193 . Training Loss: 114.347084  Validation Loss: 93.45313  Best Validation Loss: 93.45313
# Epoch: 194 . Training Loss: 57.08065  Validation Loss: 100.875626  Best Validation Loss: 93.45313
# Epoch: 195 . Training Loss: 86.291824  Validation Loss: 103.743385  Best Validation Loss: 93.45313
# Epoch: 196 . Training Loss: 91.5806  Validation Loss: 92.41492  Best Validation Loss: 92.41492
# Epoch: 197 . Training Loss: 126.25457  Validation Loss: 101.95178  Best Validation Loss: 92.41492
# Epoch: 198 . Training Loss: 82.12531  Validation Loss: 108.85481  Best Validation Loss: 92.41492
# Epoch: 199 . Training Loss: 107.71557  Validation Loss: 95.121635  Best Validation Loss: 92.41492
# Epoch: 200 . Training Loss: 99.32031  Validation Loss: 100.37752  Best Validation Loss: 92.41492
# Epoch: 201 . Training Loss: 91.40413  Validation Loss: 107.3845  Best Validation Loss: 92.41492
# Epoch: 202 . Training Loss: 88.42019  Validation Loss: 103.50513  Best Validation Loss: 92.41492
# Epoch: 203 . Training Loss: 127.325615  Validation Loss: 91.66013  Best Validation Loss: 91.66013
# Epoch: 204 . Training Loss: 94.75392  Validation Loss: 107.56392  Best Validation Loss: 91.66013
# Epoch: 205 . Training Loss: 97.5258  Validation Loss: 107.24077  Best Validation Loss: 91.66013
# Epoch: 206 . Training Loss: 118.62309  Validation Loss: 92.81543  Best Validation Loss: 91.66013
# Epoch: 207 . Training Loss: 102.3647  Validation Loss: 97.72914  Best Validation Loss: 91.66013
# Epoch: 208 . Training Loss: 90.27279  Validation Loss: 95.967896  Best Validation Loss: 91.66013
# Epoch: 209 . Training Loss: 67.89777  Validation Loss: 92.54608  Best Validation Loss: 91.66013
# Epoch: 210 . Training Loss: 52.007828  Validation Loss: 90.575905  Best Validation Loss: 90.575905
# Epoch: 211 . Training Loss: 86.28183  Validation Loss: 92.21992  Best Validation Loss: 90.575905
# Epoch: 212 . Training Loss: 81.886116  Validation Loss: 93.6827  Best Validation Loss: 90.575905
# Epoch: 213 . Training Loss: 96.73058  Validation Loss: 92.892914  Best Validation Loss: 90.575905
# Epoch: 214 . Training Loss: 87.73588  Validation Loss: 89.60539  Best Validation Loss: 89.60539
# Epoch: 215 . Training Loss: 96.124886  Validation Loss: 121.39209  Best Validation Loss: 89.60539
# Epoch: 216 . Training Loss: 107.5359  Validation Loss: 106.911934  Best Validation Loss: 89.60539
# Epoch: 217 . Training Loss: 70.86008  Validation Loss: 88.41211  Best Validation Loss: 88.41211
# Epoch: 218 . Training Loss: 67.01653  Validation Loss: 96.40208  Best Validation Loss: 88.41211
# Epoch: 219 . Training Loss: 75.72783  Validation Loss: 104.22811  Best Validation Loss: 88.41211
# Epoch: 220 . Training Loss: 106.23316  Validation Loss: 90.26767  Best Validation Loss: 88.41211
# Epoch: 221 . Training Loss: 67.708664  Validation Loss: 103.287575  Best Validation Loss: 88.41211
# Epoch: 222 . Training Loss: 92.89039  Validation Loss: 140.18852  Best Validation Loss: 88.41211
# Epoch: 223 . Training Loss: 123.71402  Validation Loss: 98.42209  Best Validation Loss: 88.41211
# Epoch: 224 . Training Loss: 66.398186  Validation Loss: 95.12369  Best Validation Loss: 88.41211
# Epoch: 225 . Training Loss: 75.435905  Validation Loss: 116.24202  Best Validation Loss: 88.41211
# Epoch: 226 . Training Loss: 105.08154  Validation Loss: 111.72745  Best Validation Loss: 88.41211
# Early stopping on epoch 227

# %% [markdown]
# ### visualization loss

# %%
# Convert the history to a pandas dataframe
df_loss_history = pd.DataFrame(loss_history, columns=['train_loss', 'val_loss'])

# plot train and validation loss
plt.figure(figsize=(10, 6))
plt.plot(df_loss_history['train_loss'], label='Train Loss')
plt.plot(df_loss_history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train vs Validation Loss over time')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation

# %%
test_true = test_lmrk
test_pred = model.predict(test_img)

print("Combine L2 And Cosine Error: ", combine_l2_cosine_loss(test_true, test_pred).numpy())
# Out:
# Combine L2 And Cosine Error:  81.39356

# %% [markdown]
# ### visualize result

# %%
def plot_sample(image, landmarks, ax):
    ax.imshow(image, cmap='gray')
    landmarks = np.reshape(landmarks, (-1, 2)) # reshape to (15, 2)
    ax.scatter(landmarks[:, 0], landmarks[:, 1], marker='o', s=10)

# suppose we have some predictions and ground truth data
predictions = model.predict(test_img)
ground_truth = test_lmrk  # assume this exists

errors = np.mean(np.abs(predictions - ground_truth), axis=1)
sorted_indices = np.argsort(errors)

# Indices of good predictions
good_indices = sorted_indices[:5]  

# Indices of bad predictions
bad_indices = sorted_indices[-5:]  

fig = plt.figure(figsize=(20,10))
for i in range(5):
    # Good predictions
    ax = fig.add_subplot(2, 5, i+1)
    plot_sample(test_img[good_indices[i]], predictions[good_indices[i]], ax)
    ax.set_title("Good prediction \nCombine L2 And Cosine Error: {:.2f}".format(errors[good_indices[i]]))

    # Bad predictions
    ax = fig.add_subplot(2, 5, i+6)
    plot_sample(test_img[bad_indices[i]], predictions[bad_indices[i]], ax)
    ax.set_title("Bad prediction \nCombine L2 And Cosine Error: {:.2f}".format(errors[bad_indices[i]]))

plt.show()
