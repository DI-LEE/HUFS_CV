# %%
import tensorflow as tf
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Load Data

# %%
def loadData():
    data = io.loadmat("face_landmark.mat")
    images = data["images"]
    landmarks = data["landmarks"]
    print("im_shape:", images.shape)
    print("landmarks_shape:", landmarks.shape)

    return images, landmarks

# %%
images, landmarks = loadData()
# Out:
# im_shape: (2140, 96, 96)
# landmarks_shape: (2140, 15, 2)

# %% [markdown]
# # Visualize Data

# %%
def visualize_data(images, landmarks, num_images):
    fig = plt.figure(figsize=(10,10))
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

    for i in range(num_images):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        ax.imshow(images[i], cmap='gray')
        for (x, y) in landmarks[i].reshape(-1, 2):
            # Plot keypoints/landmarks on the image
            ax.scatter(x, y, marker='o', s=10, color='r')

    plt.show()

# %%
visualize_data(images, landmarks, num_images=16)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### split

# %%
def split_data(data, size):
    np.random.seed(2023)
    
    idx = np.random.permutation(size)

    train_size = int(size * 0.6)
    val_size = int(size * 0.2)
    test_size = int(size * 0.2)

    train_ds = data[idx[: train_size]]
    val_ds = data[idx[train_size: train_size + val_size]]
    test_ds = data[idx[size - test_size:]]

    return train_ds, val_ds, test_ds

# %%
train_img, val_img, test_img = split_data(images, images.shape[0])

# %%
train_lmrk, val_lmrk, test_lmrk = split_data(landmarks, landmarks.shape[0])

# %% [markdown]
# ### Reshape

# %%
print(train_img.shape)
print(train_lmrk.shape)
# Out:
# (1284, 96, 96)
# (1284, 15, 2)

# %%
print(val_img.shape)
print(val_lmrk.shape)
# Out:
# (428, 96, 96)
# (428, 15, 2)

# %%
print(test_img.shape)
print(test_lmrk.shape)
# Out:
# (428, 96, 96)
# (428, 15, 2)

# %%
train_lmrk = train_lmrk.reshape((1284, -1))
val_lmrk = val_lmrk.reshape((428, -1))
test_lmrk = test_lmrk.reshape((428, -1))

# %%
print(train_lmrk.shape)
print(val_lmrk.shape)
print(test_lmrk.shape)
# Out:
# (1284, 30)
# (428, 30)
# (428, 30)

# %% [markdown]
# # Model
# * Output은 15개의 얼굴 랜드마크에 해당하는 x, y 좌표이므로 총 30개의 출력 유닛이 필요

# %%
# Define the input shape
input_layer = tf.keras.Input(shape=(96, 96, 1))

# Define the convolution and pooling layers
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(input_layer)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the tensor output for the Fully Connected layer
x = tf.keras.layers.Flatten()(x)

# Define the fully connected layer
x = tf.keras.layers.Dense(64, activation='relu')(x)

# Define the output layer (30 units for 15 landmarks x and y coordinates)
output_layer = tf.keras.layers.Dense(30)(x)

# Create the model
model = tf.keras.Model(input_layer, output_layer)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d (Conv2D)             (None, 94, 94, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 47, 47, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 45, 45, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 30)                1950
#
# =================================================================
# Total params: 132,542
# Trainable params: 132,542
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Predict

# %%
@tf.function
def predict(x):
    return model(x, training=False)

# %% [markdown]
# # Optimization

# %%
@tf.function
def optimize(x,y_true,loss_function):
    with tf.GradientTape() as tape:
        y_pred = predict(x)
        loss = loss_function(y_pred, y_true)
    grads = tape.gradient(loss, model.trainable_variables)
    opt.apply_gradients(zip(grads, model.trainable_variables))
    return loss

# %%
opt = tf.keras.optimizers.Adam(learning_rate=1e-3)

# %% [markdown]
# # Loss
# * 실제 레이블(y_true)와 모델의 예측 결과(y)를 입력

# %%
@tf.function
def l1_loss(y_pred, y_true):
    return tf.reduce_mean(tf.abs(y_true - y_pred))

@tf.function
def l2_loss(y_pred, y_true):
    return tf.reduce_mean(tf.square(y_true - y_pred))

@tf.function
def cosine_loss(y_pred, y_true):
    # Normalize each vector
    y_true_normalized = tf.nn.l2_normalize(y_true, axis=-1)
    y_pred_normalized = tf.nn.l2_normalize(y_pred, axis=-1)
    # Compute the dot product (cosine similarity)
    dot_product = tf.reduce_sum(y_true_normalized * y_pred_normalized, axis=-1)
    # Subtract the dot product from 1 to get the loss
    return 1 - tf.reduce_mean(dot_product)

# %%
def combine_l2_cosine_loss(y_pred, y_true, lamda=0.6):
    return l2_loss(y_pred, y_true) + lamda*cosine_loss(y_pred, y_true)

# %% [markdown]
# # Train & Evaluation

# %%
""" start training """
loss_function = combine_l2_cosine_loss

max_epochs = 1000
batch_size = 32


loss_history = []
val_loss_best = np.inf
train_size = int(images.shape[0] * 0.6)

#Early stopping hyperparameter
patience = 50  # number of epochs to wait before stopping if there is no improvement
wait = 0  # counter for epochs without improvement


for epoch in range(max_epochs):
    # get a minibatch
    idx = np.random.permutation(train_size)
    batch_idx = idx[:batch_size]

    # optimize
    train_loss = optimize(train_img[batch_idx], train_lmrk[batch_idx], loss_function)
    train_loss = train_loss.numpy()

    # evaluate on val_set
    y = predict(val_img)
    val_loss = loss_function(y, val_lmrk).numpy()

    # Early stopping check
    if val_loss < val_loss_best:
        val_loss_best = val_loss
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            print(f'Early stopping on epoch {epoch}')
            break
        
    print('Epoch:', epoch, '. Training Loss:', train_loss, ' Validation Loss:', val_loss, ' Best Validation Loss:', val_loss_best)
    loss_history.append([train_loss, val_loss])
# Out:
# Epoch: 0 . Training Loss: 2562.3123  Validation Loss: 1898.0013  Best Validation Loss: 1898.0013
# Epoch: 1 . Training Loss: 1887.6522  Validation Loss: 1624.3604  Best Validation Loss: 1624.3604
# Epoch: 2 . Training Loss: 1638.3267  Validation Loss: 1364.4559  Best Validation Loss: 1364.4559
# Epoch: 3 . Training Loss: 1393.1592  Validation Loss: 1137.206  Best Validation Loss: 1137.206
# Epoch: 4 . Training Loss: 1106.9945  Validation Loss: 1013.47736  Best Validation Loss: 1013.47736
# Epoch: 5 . Training Loss: 1014.27747  Validation Loss: 904.6736  Best Validation Loss: 904.6736
# Epoch: 6 . Training Loss: 910.7976  Validation Loss: 802.3546  Best Validation Loss: 802.3546
# Epoch: 7 . Training Loss: 775.3213  Validation Loss: 732.8443  Best Validation Loss: 732.8443
# Epoch: 8 . Training Loss: 739.1791  Validation Loss: 669.3442  Best Validation Loss: 669.3442
# Epoch: 9 . Training Loss: 663.4334  Validation Loss: 623.7655  Best Validation Loss: 623.7655
# Epoch: 10 . Training Loss: 593.5582  Validation Loss: 609.72894  Best Validation Loss: 609.72894
# Epoch: 11 . Training Loss: 578.1959  Validation Loss: 581.7323  Best Validation Loss: 581.7323
# Epoch: 12 . Training Loss: 571.9703  Validation Loss: 534.2693  Best Validation Loss: 534.2693
# Epoch: 13 . Training Loss: 548.0123  Validation Loss: 504.2769  Best Validation Loss: 504.2769
# Epoch: 14 . Training Loss: 485.4874  Validation Loss: 473.5957  Best Validation Loss: 473.5957
# Epoch: 15 . Training Loss: 464.32468  Validation Loss: 433.91974  Best Validation Loss: 433.91974
# Epoch: 16 . Training Loss: 431.7762  Validation Loss: 394.13907  Best Validation Loss: 394.13907
# Epoch: 17 . Training Loss: 430.7055  Validation Loss: 357.27982  Best Validation Loss: 357.27982
# Epoch: 18 . Training Loss: 335.41736  Validation Loss: 329.05295  Best Validation Loss: 329.05295
# Epoch: 19 . Training Loss: 326.26865  Validation Loss: 306.27417  Best Validation Loss: 306.27417
# Epoch: 20 . Training Loss: 285.70047  Validation Loss: 288.30368  Best Validation Loss: 288.30368
# Epoch: 21 . Training Loss: 268.37396  Validation Loss: 272.85797  Best Validation Loss: 272.85797
# Epoch: 22 . Training Loss: 275.17166  Validation Loss: 257.59225  Best Validation Loss: 257.59225
# Epoch: 23 . Training Loss: 248.4379  Validation Loss: 246.86931  Best Validation Loss: 246.86931
# Epoch: 24 . Training Loss: 246.0915  Validation Loss: 225.05823  Best Validation Loss: 225.05823
# Epoch: 25 . Training Loss: 222.34827  Validation Loss: 225.03178  Best Validation Loss: 225.03178
# Epoch: 26 . Training Loss: 264.087  Validation Loss: 193.89365  Best Validation Loss: 193.89365
# Epoch: 27 . Training Loss: 209.223  Validation Loss: 204.01035  Best Validation Loss: 193.89365
# Epoch: 28 . Training Loss: 215.90227  Validation Loss: 192.42538  Best Validation Loss: 192.42538
# Epoch: 29 . Training Loss: 192.24554  Validation Loss: 170.02322  Best Validation Loss: 170.02322
# Epoch: 30 . Training Loss: 161.26514  Validation Loss: 170.22821  Best Validation Loss: 170.02322
# Epoch: 31 . Training Loss: 183.20888  Validation Loss: 165.34796  Best Validation Loss: 165.34796
# Epoch: 32 . Training Loss: 141.07278  Validation Loss: 158.70758  Best Validation Loss: 158.70758
# Epoch: 33 . Training Loss: 164.09673  Validation Loss: 147.66383  Best Validation Loss: 147.66383
# Epoch: 34 . Training Loss: 114.57788  Validation Loss: 146.04149  Best Validation Loss: 146.04149
# Epoch: 35 . Training Loss: 131.12743  Validation Loss: 173.25072  Best Validation Loss: 146.04149
# Epoch: 36 . Training Loss: 135.02855  Validation Loss: 167.85512  Best Validation Loss: 146.04149
# Epoch: 37 . Training Loss: 194.33363  Validation Loss: 143.11229  Best Validation Loss: 143.11229
# Epoch: 38 . Training Loss: 164.8705  Validation Loss: 146.6352  Best Validation Loss: 143.11229
# Epoch: 39 . Training Loss: 230.46878  Validation Loss: 141.32326  Best Validation Loss: 141.32326
# Epoch: 40 . Training Loss: 116.39676  Validation Loss: 135.493  Best Validation Loss: 135.493
# Epoch: 41 . Training Loss: 118.95902  Validation Loss: 134.97173  Best Validation Loss: 134.97173
# Epoch: 42 . Training Loss: 107.12631  Validation Loss: 133.01656  Best Validation Loss: 133.01656
# Epoch: 43 . Training Loss: 160.99258  Validation Loss: 135.04752  Best Validation Loss: 133.01656
# Epoch: 44 . Training Loss: 133.21788  Validation Loss: 130.034  Best Validation Loss: 130.034
# Epoch: 45 . Training Loss: 112.61688  Validation Loss: 131.3732  Best Validation Loss: 130.034
# Epoch: 46 . Training Loss: 158.6594  Validation Loss: 129.8345  Best Validation Loss: 129.8345
# Epoch: 47 . Training Loss: 158.58224  Validation Loss: 130.55577  Best Validation Loss: 129.8345
# Epoch: 48 . Training Loss: 107.22881  Validation Loss: 135.87837  Best Validation Loss: 129.8345
# Epoch: 49 . Training Loss: 142.26694  Validation Loss: 126.65606  Best Validation Loss: 126.65606
# Epoch: 50 . Training Loss: 104.32603  Validation Loss: 125.253456  Best Validation Loss: 125.253456
# Epoch: 51 . Training Loss: 118.31464  Validation Loss: 129.43607  Best Validation Loss: 125.253456
# Epoch: 52 . Training Loss: 118.01746  Validation Loss: 125.65907  Best Validation Loss: 125.253456
# Epoch: 53 . Training Loss: 120.69532  Validation Loss: 122.79675  Best Validation Loss: 122.79675
# Epoch: 54 . Training Loss: 100.32284  Validation Loss: 129.34355  Best Validation Loss: 122.79675
# Epoch: 55 . Training Loss: 129.42033  Validation Loss: 128.12599  Best Validation Loss: 122.79675
# Epoch: 56 . Training Loss: 145.0374  Validation Loss: 174.82956  Best Validation Loss: 122.79675
# Epoch: 57 . Training Loss: 205.33217  Validation Loss: 154.22438  Best Validation Loss: 122.79675
# Epoch: 58 . Training Loss: 164.70642  Validation Loss: 119.58305  Best Validation Loss: 119.58305
# Epoch: 59 . Training Loss: 118.817604  Validation Loss: 126.969574  Best Validation Loss: 119.58305
# Epoch: 60 . Training Loss: 93.95624  Validation Loss: 124.98789  Best Validation Loss: 119.58305
# Epoch: 61 . Training Loss: 149.93102  Validation Loss: 122.09999  Best Validation Loss: 119.58305
# Epoch: 62 . Training Loss: 183.89697  Validation Loss: 131.51083  Best Validation Loss: 119.58305
# Epoch: 63 . Training Loss: 142.96582  Validation Loss: 119.011185  Best Validation Loss: 119.011185
# Epoch: 64 . Training Loss: 93.555695  Validation Loss: 121.38799  Best Validation Loss: 119.011185
# Epoch: 65 . Training Loss: 128.56075  Validation Loss: 122.53493  Best Validation Loss: 119.011185
# Epoch: 66 . Training Loss: 98.52572  Validation Loss: 116.247215  Best Validation Loss: 116.247215
# Epoch: 67 . Training Loss: 113.54491  Validation Loss: 115.76963  Best Validation Loss: 115.76963
# Epoch: 68 . Training Loss: 92.146736  Validation Loss: 115.74949  Best Validation Loss: 115.74949
# Epoch: 69 . Training Loss: 128.79901  Validation Loss: 114.38339  Best Validation Loss: 114.38339
# Epoch: 70 . Training Loss: 115.33553  Validation Loss: 115.07253  Best Validation Loss: 114.38339
# Epoch: 71 . Training Loss: 125.15978  Validation Loss: 116.91381  Best Validation Loss: 114.38339
# Epoch: 72 . Training Loss: 112.64489  Validation Loss: 113.365654  Best Validation Loss: 113.365654
# Epoch: 73 . Training Loss: 106.544174  Validation Loss: 123.01724  Best Validation Loss: 113.365654
# Epoch: 74 . Training Loss: 91.58157  Validation Loss: 113.881516  Best Validation Loss: 113.365654
# Epoch: 75 . Training Loss: 132.82819  Validation Loss: 114.88278  Best Validation Loss: 113.365654
# Epoch: 76 . Training Loss: 108.23711  Validation Loss: 116.38957  Best Validation Loss: 113.365654
# Epoch: 77 . Training Loss: 136.44048  Validation Loss: 111.94549  Best Validation Loss: 111.94549
# Epoch: 78 . Training Loss: 91.29985  Validation Loss: 112.63268  Best Validation Loss: 111.94549
# Epoch: 79 . Training Loss: 93.097786  Validation Loss: 117.85952  Best Validation Loss: 111.94549
# Epoch: 80 . Training Loss: 116.12218  Validation Loss: 113.332146  Best Validation Loss: 111.94549
# Epoch: 81 . Training Loss: 118.67406  Validation Loss: 113.19766  Best Validation Loss: 111.94549
# Epoch: 82 . Training Loss: 93.83675  Validation Loss: 121.568  Best Validation Loss: 111.94549
# Epoch: 83 . Training Loss: 66.74387  Validation Loss: 123.882454  Best Validation Loss: 111.94549
# Epoch: 84 . Training Loss: 112.49194  Validation Loss: 110.89161  Best Validation Loss: 110.89161
# Epoch: 85 . Training Loss: 99.79962  Validation Loss: 118.788956  Best Validation Loss: 110.89161
# Epoch: 86 . Training Loss: 89.06724  Validation Loss: 121.14329  Best Validation Loss: 110.89161
# Epoch: 87 . Training Loss: 127.96757  Validation Loss: 110.74502  Best Validation Loss: 110.74502
# Epoch: 88 . Training Loss: 129.73111  Validation Loss: 150.2202  Best Validation Loss: 110.74502
# Epoch: 89 . Training Loss: 141.96767  Validation Loss: 131.36166  Best Validation Loss: 110.74502
# Epoch: 90 . Training Loss: 86.92916  Validation Loss: 108.90349  Best Validation Loss: 108.90349
# Epoch: 91 . Training Loss: 119.91774  Validation Loss: 184.30257  Best Validation Loss: 108.90349
# Epoch: 92 . Training Loss: 195.32703  Validation Loss: 129.72438  Best Validation Loss: 108.90349
# Epoch: 93 . Training Loss: 151.15184  Validation Loss: 115.052124  Best Validation Loss: 108.90349
# Epoch: 94 . Training Loss: 97.67844  Validation Loss: 137.57838  Best Validation Loss: 108.90349
# Epoch: 95 . Training Loss: 93.67746  Validation Loss: 136.25734  Best Validation Loss: 108.90349
# Epoch: 96 . Training Loss: 127.67368  Validation Loss: 110.32724  Best Validation Loss: 108.90349
# Epoch: 97 . Training Loss: 90.30198  Validation Loss: 135.26622  Best Validation Loss: 108.90349
# Epoch: 98 . Training Loss: 136.30458  Validation Loss: 156.82623  Best Validation Loss: 108.90349
# Epoch: 99 . Training Loss: 158.50708  Validation Loss: 108.29846  Best Validation Loss: 108.29846
# Epoch: 100 . Training Loss: 107.78158  Validation Loss: 125.07629  Best Validation Loss: 108.29846
# Epoch: 101 . Training Loss: 133.76608  Validation Loss: 124.938644  Best Validation Loss: 108.29846
# Epoch: 102 . Training Loss: 106.81592  Validation Loss: 112.12995  Best Validation Loss: 108.29846
# Epoch: 103 . Training Loss: 93.06521  Validation Loss: 108.6783  Best Validation Loss: 108.29846
# Epoch: 104 . Training Loss: 74.138916  Validation Loss: 113.75458  Best Validation Loss: 108.29846
# Epoch: 105 . Training Loss: 111.840614  Validation Loss: 110.59617  Best Validation Loss: 108.29846
# Epoch: 106 . Training Loss: 99.174644  Validation Loss: 111.00638  Best Validation Loss: 108.29846
# Epoch: 107 . Training Loss: 89.43714  Validation Loss: 107.71898  Best Validation Loss: 107.71898
# Epoch: 108 . Training Loss: 100.48417  Validation Loss: 110.73473  Best Validation Loss: 107.71898
# Epoch: 109 . Training Loss: 131.42064  Validation Loss: 110.51211  Best Validation Loss: 107.71898
# Epoch: 110 . Training Loss: 83.060486  Validation Loss: 106.79401  Best Validation Loss: 106.79401
# Epoch: 111 . Training Loss: 126.44158  Validation Loss: 108.96632  Best Validation Loss: 106.79401
# Epoch: 112 . Training Loss: 119.40348  Validation Loss: 108.34185  Best Validation Loss: 106.79401
# Epoch: 113 . Training Loss: 87.74239  Validation Loss: 107.30315  Best Validation Loss: 106.79401
# Epoch: 114 . Training Loss: 81.70726  Validation Loss: 105.91735  Best Validation Loss: 105.91735
# Epoch: 115 . Training Loss: 97.78189  Validation Loss: 105.944855  Best Validation Loss: 105.91735
# Epoch: 116 . Training Loss: 62.23202  Validation Loss: 110.284355  Best Validation Loss: 105.91735
# Epoch: 117 . Training Loss: 131.39835  Validation Loss: 108.466064  Best Validation Loss: 105.91735
# Epoch: 118 . Training Loss: 89.77572  Validation Loss: 104.33212  Best Validation Loss: 104.33212
# Epoch: 119 . Training Loss: 98.14601  Validation Loss: 114.48658  Best Validation Loss: 104.33212
# Epoch: 120 . Training Loss: 117.329544  Validation Loss: 105.8991  Best Validation Loss: 104.33212
# Epoch: 121 . Training Loss: 87.64465  Validation Loss: 103.71636  Best Validation Loss: 103.71636
# Epoch: 122 . Training Loss: 148.05908  Validation Loss: 104.64911  Best Validation Loss: 103.71636
# Epoch: 123 . Training Loss: 135.85913  Validation Loss: 106.15173  Best Validation Loss: 103.71636
# Epoch: 124 . Training Loss: 70.93222  Validation Loss: 128.22035  Best Validation Loss: 103.71636
# Epoch: 125 . Training Loss: 111.983604  Validation Loss: 111.566025  Best Validation Loss: 103.71636
# Epoch: 126 . Training Loss: 110.96585  Validation Loss: 117.03125  Best Validation Loss: 103.71636
# Epoch: 127 . Training Loss: 93.38583  Validation Loss: 156.93642  Best Validation Loss: 103.71636
# Epoch: 128 . Training Loss: 126.41549  Validation Loss: 146.11711  Best Validation Loss: 103.71636
# Epoch: 129 . Training Loss: 119.9348  Validation Loss: 106.046425  Best Validation Loss: 103.71636
# Epoch: 130 . Training Loss: 73.441956  Validation Loss: 123.991325  Best Validation Loss: 103.71636
# Early stopping on epoch 131

# %% [markdown]
# ### visualization loss

# %%
# Convert the history to a pandas dataframe
df_loss_history = pd.DataFrame(loss_history, columns=['train_loss', 'val_loss'])

# plot train and validation loss
plt.figure(figsize=(10, 6))
plt.plot(df_loss_history['train_loss'], label='Train Loss')
plt.plot(df_loss_history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train vs Validation Loss over time')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation

# %%
test_true = test_lmrk
test_pred = model.predict(test_img)

print("Combine L2 And Cosine Error: ", combine_l2_cosine_loss(test_true, test_pred).numpy())
# Out:
# Combine L2 And Cosine Error:  128.464

# %% [markdown]
# ### visualize result

# %%
def plot_sample(image, landmarks, ax):
    ax.imshow(image, cmap='gray')
    landmarks = np.reshape(landmarks, (-1, 2)) # reshape to (15, 2)
    ax.scatter(landmarks[:, 0], landmarks[:, 1], marker='o', s=10)

# suppose we have some predictions and ground truth data
predictions = model.predict(test_img)
ground_truth = test_lmrk  # assume this exists

errors = np.mean(np.abs(predictions - ground_truth), axis=1)
sorted_indices = np.argsort(errors)

# Indices of good predictions
good_indices = sorted_indices[:5]  

# Indices of bad predictions
bad_indices = sorted_indices[-5:]  

fig = plt.figure(figsize=(20,10))
for i in range(5):
    # Good predictions
    ax = fig.add_subplot(2, 5, i+1)
    plot_sample(test_img[good_indices[i]], predictions[good_indices[i]], ax)
    ax.set_title("Good prediction \nCombine L2 And Cosine Error: {:.2f}".format(errors[good_indices[i]]))

    # Bad predictions
    ax = fig.add_subplot(2, 5, i+6)
    plot_sample(test_img[bad_indices[i]], predictions[bad_indices[i]], ax)
    ax.set_title("Bad prediction \nCombine L2 And Cosine Error: {:.2f}".format(errors[bad_indices[i]]))

plt.show()
