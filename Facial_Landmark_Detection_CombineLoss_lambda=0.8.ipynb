# %%
import tensorflow as tf
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Load Data

# %%
def loadData():
    data = io.loadmat("face_landmark.mat")
    images = data["images"]
    landmarks = data["landmarks"]
    print("im_shape:", images.shape)
    print("landmarks_shape:", landmarks.shape)

    return images, landmarks

# %%
images, landmarks = loadData()
# Out:
# im_shape: (2140, 96, 96)
# landmarks_shape: (2140, 15, 2)

# %% [markdown]
# # Visualize Data

# %%
def visualize_data(images, landmarks, num_images):
    fig = plt.figure(figsize=(10,10))
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

    for i in range(num_images):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        ax.imshow(images[i], cmap='gray')
        for (x, y) in landmarks[i].reshape(-1, 2):
            # Plot keypoints/landmarks on the image
            ax.scatter(x, y, marker='o', s=10, color='r')

    plt.show()

# %%
visualize_data(images, landmarks, num_images=16)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### split

# %%
def split_data(data, size):
    np.random.seed(2023)
    
    idx = np.random.permutation(size)

    train_size = int(size * 0.6)
    val_size = int(size * 0.2)
    test_size = int(size * 0.2)

    train_ds = data[idx[: train_size]]
    val_ds = data[idx[train_size: train_size + val_size]]
    test_ds = data[idx[size - test_size:]]

    return train_ds, val_ds, test_ds

# %%
train_img, val_img, test_img = split_data(images, images.shape[0])

# %%
train_lmrk, val_lmrk, test_lmrk = split_data(landmarks, landmarks.shape[0])

# %% [markdown]
# ### Reshape

# %%
print(train_img.shape)
print(train_lmrk.shape)
# Out:
# (1284, 96, 96)
# (1284, 15, 2)

# %%
print(val_img.shape)
print(val_lmrk.shape)
# Out:
# (428, 96, 96)
# (428, 15, 2)

# %%
print(test_img.shape)
print(test_lmrk.shape)
# Out:
# (428, 96, 96)
# (428, 15, 2)

# %%
train_lmrk = train_lmrk.reshape((1284, -1))
val_lmrk = val_lmrk.reshape((428, -1))
test_lmrk = test_lmrk.reshape((428, -1))

# %%
print(train_lmrk.shape)
print(val_lmrk.shape)
print(test_lmrk.shape)
# Out:
# (1284, 30)
# (428, 30)
# (428, 30)

# %% [markdown]
# # Model
# * Output은 15개의 얼굴 랜드마크에 해당하는 x, y 좌표이므로 총 30개의 출력 유닛이 필요

# %%
# Define the input shape
input_layer = tf.keras.Input(shape=(96, 96, 1))

# Define the convolution and pooling layers
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(input_layer)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the tensor output for the Fully Connected layer
x = tf.keras.layers.Flatten()(x)

# Define the fully connected layer
x = tf.keras.layers.Dense(64, activation='relu')(x)

# Define the output layer (30 units for 15 landmarks x and y coordinates)
output_layer = tf.keras.layers.Dense(30)(x)

# Create the model
model = tf.keras.Model(input_layer, output_layer)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d (Conv2D)             (None, 94, 94, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 47, 47, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 45, 45, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 30)                1950
#
# =================================================================
# Total params: 132,542
# Trainable params: 132,542
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Predict

# %%
@tf.function
def predict(x):
    return model(x, training=False)

# %% [markdown]
# # Optimization

# %%
@tf.function
def optimize(x,y_true,loss_function):
    with tf.GradientTape() as tape:
        y_pred = predict(x)
        loss = loss_function(y_pred, y_true)
    grads = tape.gradient(loss, model.trainable_variables)
    opt.apply_gradients(zip(grads, model.trainable_variables))
    return loss

# %%
opt = tf.keras.optimizers.Adam(learning_rate=1e-3)

# %% [markdown]
# # Loss
# * 실제 레이블(y_true)와 모델의 예측 결과(y)를 입력

# %%
@tf.function
def l1_loss(y_pred, y_true):
    return tf.reduce_mean(tf.abs(y_true - y_pred))

@tf.function
def l2_loss(y_pred, y_true):
    return tf.reduce_mean(tf.square(y_true - y_pred))

@tf.function
def cosine_loss(y_pred, y_true):
    # Normalize each vector
    y_true_normalized = tf.nn.l2_normalize(y_true, axis=-1)
    y_pred_normalized = tf.nn.l2_normalize(y_pred, axis=-1)
    # Compute the dot product (cosine similarity)
    dot_product = tf.reduce_sum(y_true_normalized * y_pred_normalized, axis=-1)
    # Subtract the dot product from 1 to get the loss
    return 1 - tf.reduce_mean(dot_product)

# %%
def combine_l2_cosine_loss(y_pred, y_true, lamda=0.8):
    return l2_loss(y_pred, y_true) + lamda*cosine_loss(y_pred, y_true)

# %% [markdown]
# # Train & Evaluation

# %%
""" start training """
loss_function = combine_l2_cosine_loss

max_epochs = 1000
batch_size = 32


loss_history = []
val_loss_best = np.inf
train_size = int(images.shape[0] * 0.6)

#Early stopping hyperparameter
patience = 50  # number of epochs to wait before stopping if there is no improvement
wait = 0  # counter for epochs without improvement


for epoch in range(max_epochs):
    # get a minibatch
    idx = np.random.permutation(train_size)
    batch_idx = idx[:batch_size]

    # optimize
    train_loss = optimize(train_img[batch_idx], train_lmrk[batch_idx], loss_function)
    train_loss = train_loss.numpy()

    # evaluate on val_set
    y = predict(val_img)
    val_loss = loss_function(y, val_lmrk).numpy()

    # Early stopping check
    if val_loss < val_loss_best:
        val_loss_best = val_loss
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            print(f'Early stopping on epoch {epoch}')
            break
        
    print('Epoch:', epoch, '. Training Loss:', train_loss, ' Validation Loss:', val_loss, ' Best Validation Loss:', val_loss_best)
    loss_history.append([train_loss, val_loss])
# Out:
# Epoch: 0 . Training Loss: 2605.8647  Validation Loss: 2057.2568  Best Validation Loss: 2057.2568
# Epoch: 1 . Training Loss: 2043.2325  Validation Loss: 1627.6146  Best Validation Loss: 1627.6146
# Epoch: 2 . Training Loss: 1627.2018  Validation Loss: 1358.8888  Best Validation Loss: 1358.8888
# Epoch: 3 . Training Loss: 1371.0347  Validation Loss: 1189.4338  Best Validation Loss: 1189.4338
# Epoch: 4 . Training Loss: 1188.4805  Validation Loss: 993.3504  Best Validation Loss: 993.3504
# Epoch: 5 . Training Loss: 1030.9099  Validation Loss: 913.11786  Best Validation Loss: 913.11786
# Epoch: 6 . Training Loss: 926.2103  Validation Loss: 902.602  Best Validation Loss: 902.602
# Epoch: 7 . Training Loss: 880.35156  Validation Loss: 878.14716  Best Validation Loss: 878.14716
# Epoch: 8 . Training Loss: 883.84796  Validation Loss: 832.13367  Best Validation Loss: 832.13367
# Epoch: 9 . Training Loss: 826.2335  Validation Loss: 768.9621  Best Validation Loss: 768.9621
# Epoch: 10 . Training Loss: 751.71185  Validation Loss: 712.5375  Best Validation Loss: 712.5375
# Epoch: 11 . Training Loss: 695.7132  Validation Loss: 663.27167  Best Validation Loss: 663.27167
# Epoch: 12 . Training Loss: 659.8099  Validation Loss: 610.31213  Best Validation Loss: 610.31213
# Epoch: 13 . Training Loss: 607.6472  Validation Loss: 557.7727  Best Validation Loss: 557.7727
# Epoch: 14 . Training Loss: 531.7959  Validation Loss: 518.2708  Best Validation Loss: 518.2708
# Epoch: 15 . Training Loss: 507.92862  Validation Loss: 486.81183  Best Validation Loss: 486.81183
# Epoch: 16 . Training Loss: 486.8766  Validation Loss: 460.6809  Best Validation Loss: 460.6809
# Epoch: 17 . Training Loss: 504.56348  Validation Loss: 431.54327  Best Validation Loss: 431.54327
# Epoch: 18 . Training Loss: 422.77127  Validation Loss: 408.08603  Best Validation Loss: 408.08603
# Epoch: 19 . Training Loss: 405.90134  Validation Loss: 382.52554  Best Validation Loss: 382.52554
# Epoch: 20 . Training Loss: 359.92316  Validation Loss: 352.35953  Best Validation Loss: 352.35953
# Epoch: 21 . Training Loss: 336.78952  Validation Loss: 320.61523  Best Validation Loss: 320.61523
# Epoch: 22 . Training Loss: 324.64386  Validation Loss: 299.2735  Best Validation Loss: 299.2735
# Epoch: 86 . Training Loss: 89.912636  Validation Loss: 131.62015  Best Validation Loss: 115.13678
# Epoch: 87 . Training Loss: 126.02046  Validation Loss: 114.39634  Best Validation Loss: 114.39634
# Epoch: 88 . Training Loss: 139.41254  Validation Loss: 153.41832  Best Validation Loss: 114.39634
# Epoch: 89 . Training Loss: 147.39525  Validation Loss: 142.25058  Best Validation Loss: 114.39634
# Epoch: 90 . Training Loss: 96.03609  Validation Loss: 113.49195  Best Validation Loss: 113.49195
# Epoch: 91 . Training Loss: 137.63326  Validation Loss: 168.82158  Best Validation Loss: 113.49195
# Epoch: 92 . Training Loss: 168.52304  Validation Loss: 160.39053  Best Validation Loss: 113.49195
# Epoch: 93 . Training Loss: 186.95631  Validation Loss: 112.802475  Best Validation Loss: 112.802475
# Epoch: 94 . Training Loss: 96.330505  Validation Loss: 132.83904  Best Validation Loss: 112.802475
# Epoch: 95 . Training Loss: 95.43666  Validation Loss: 153.19655  Best Validation Loss: 112.802475
# Epoch: 96 . Training Loss: 149.23532  Validation Loss: 129.31575  Best Validation Loss: 112.802475
# Epoch: 97 . Training Loss: 125.74446  Validation Loss: 118.1792  Best Validation Loss: 112.802475
# Epoch: 98 . Training Loss: 116.51739  Validation Loss: 156.95859  Best Validation Loss: 112.802475
# Epoch: 99 . Training Loss: 155.27887  Validation Loss: 121.82871  Best Validation Loss: 112.802475
# Epoch: 100 . Training Loss: 121.26782  Validation Loss: 113.76327  Best Validation Loss: 112.802475
# Epoch: 101 . Training Loss: 106.62709  Validation Loss: 118.28944  Best Validation Loss: 112.802475
# Epoch: 102 . Training Loss: 95.87166  Validation Loss: 120.62508  Best Validation Loss: 112.802475
# Early stopping on epoch 103

# %% [markdown]
# ### visualization loss

# %%
# Convert the history to a pandas dataframe
df_loss_history = pd.DataFrame(loss_history, columns=['train_loss', 'val_loss'])

# plot train and validation loss
plt.figure(figsize=(10, 6))
plt.plot(df_loss_history['train_loss'], label='Train Loss')
plt.plot(df_loss_history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train vs Validation Loss over time')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation

# %%
test_true = test_lmrk
test_pred = model.predict(test_img)

print("Combine L2 And Cosine Error: ", combine_l2_cosine_loss(test_true, test_pred).numpy())
# Out:
# Combine L2 And Cosine Error:  110.65175

# %% [markdown]
# ### visualize result

# %%
def plot_sample(image, landmarks, ax):
    ax.imshow(image, cmap='gray')
    landmarks = np.reshape(landmarks, (-1, 2)) # reshape to (15, 2)
    ax.scatter(landmarks[:, 0], landmarks[:, 1], marker='o', s=10)

# suppose we have some predictions and ground truth data
predictions = model.predict(test_img)
ground_truth = test_lmrk  # assume this exists

errors = np.mean(np.abs(predictions - ground_truth), axis=1)
sorted_indices = np.argsort(errors)

# Indices of good predictions
good_indices = sorted_indices[:5]  

# Indices of bad predictions
bad_indices = sorted_indices[-5:]  

fig = plt.figure(figsize=(20,10))
for i in range(5):
    # Good predictions
    ax = fig.add_subplot(2, 5, i+1)
    plot_sample(test_img[good_indices[i]], predictions[good_indices[i]], ax)
    ax.set_title("Good prediction \nCombine L2 And Cosine Error: {:.2f}".format(errors[good_indices[i]]))

    # Bad predictions
    ax = fig.add_subplot(2, 5, i+6)
    plot_sample(test_img[bad_indices[i]], predictions[bad_indices[i]], ax)
    ax.set_title("Bad prediction \nCombine L2 And Cosine Error: {:.2f}".format(errors[bad_indices[i]]))

plt.show()
