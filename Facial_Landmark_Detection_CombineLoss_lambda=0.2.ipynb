# %%
import tensorflow as tf
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Load Data

# %%
def loadData():
    data = io.loadmat("face_landmark.mat")
    images = data["images"]
    landmarks = data["landmarks"]
    print("im_shape:", images.shape)
    print("landmarks_shape:", landmarks.shape)

    return images, landmarks

# %%
images, landmarks = loadData()
# Out:
# im_shape: (2140, 96, 96)
# landmarks_shape: (2140, 15, 2)

# %% [markdown]
# # Visualize Data

# %%
def visualize_data(images, landmarks, num_images):
    fig = plt.figure(figsize=(10,10))
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

    for i in range(num_images):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        ax.imshow(images[i], cmap='gray')
        for (x, y) in landmarks[i].reshape(-1, 2):
            # Plot keypoints/landmarks on the image
            ax.scatter(x, y, marker='o', s=10, color='r')

    plt.show()

# %%
visualize_data(images, landmarks, num_images=16)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### split

# %%
def split_data(data, size):
    np.random.seed(2023)
    
    idx = np.random.permutation(size)

    train_size = int(size * 0.6)
    val_size = int(size * 0.2)
    test_size = int(size * 0.2)

    train_ds = data[idx[: train_size]]
    val_ds = data[idx[train_size: train_size + val_size]]
    test_ds = data[idx[size - test_size:]]

    return train_ds, val_ds, test_ds

# %%
train_img, val_img, test_img = split_data(images, images.shape[0])

# %%
train_lmrk, val_lmrk, test_lmrk = split_data(landmarks, landmarks.shape[0])

# %% [markdown]
# ### Reshape

# %%
print(train_img.shape)
print(train_lmrk.shape)
# Out:
# (1284, 96, 96)
# (1284, 15, 2)

# %%
print(val_img.shape)
print(val_lmrk.shape)
# Out:
# (428, 96, 96)
# (428, 15, 2)

# %%
print(test_img.shape)
print(test_lmrk.shape)
# Out:
# (428, 96, 96)
# (428, 15, 2)

# %%
train_lmrk = train_lmrk.reshape((1284, -1))
val_lmrk = val_lmrk.reshape((428, -1))
test_lmrk = test_lmrk.reshape((428, -1))

# %%
print(train_lmrk.shape)
print(val_lmrk.shape)
print(test_lmrk.shape)
# Out:
# (1284, 30)
# (428, 30)
# (428, 30)

# %% [markdown]
# # Model
# * Output은 15개의 얼굴 랜드마크에 해당하는 x, y 좌표이므로 총 30개의 출력 유닛이 필요

# %%
# Define the input shape
input_layer = tf.keras.Input(shape=(96, 96, 1))

# Define the convolution and pooling layers
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(input_layer)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the tensor output for the Fully Connected layer
x = tf.keras.layers.Flatten()(x)

# Define the fully connected layer
x = tf.keras.layers.Dense(64, activation='relu')(x)

# Define the output layer (30 units for 15 landmarks x and y coordinates)
output_layer = tf.keras.layers.Dense(30)(x)

# Create the model
model = tf.keras.Model(input_layer, output_layer)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d (Conv2D)             (None, 94, 94, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 47, 47, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 45, 45, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 30)                1950
#
# =================================================================
# Total params: 132,542
# Trainable params: 132,542
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Predict

# %%
@tf.function
def predict(x):
    return model(x, training=False)

# %% [markdown]
# # Optimization

# %%
@tf.function
def optimize(x,y_true,loss_function):
    with tf.GradientTape() as tape:
        y_pred = predict(x)
        loss = loss_function(y_pred, y_true)
    grads = tape.gradient(loss, model.trainable_variables)
    opt.apply_gradients(zip(grads, model.trainable_variables))
    return loss

# %%
opt = tf.keras.optimizers.Adam(learning_rate=1e-3)

# %% [markdown]
# # Loss
# * 실제 레이블(y_true)와 모델의 예측 결과(y)를 입력

# %%
@tf.function
def l1_loss(y_pred, y_true):
    return tf.reduce_mean(tf.abs(y_true - y_pred))

@tf.function
def l2_loss(y_pred, y_true):
    return tf.reduce_mean(tf.square(y_true - y_pred))

@tf.function
def cosine_loss(y_pred, y_true):
    # Normalize each vector
    y_true_normalized = tf.nn.l2_normalize(y_true, axis=-1)
    y_pred_normalized = tf.nn.l2_normalize(y_pred, axis=-1)
    # Compute the dot product (cosine similarity)
    dot_product = tf.reduce_sum(y_true_normalized * y_pred_normalized, axis=-1)
    # Subtract the dot product from 1 to get the loss
    return 1 - tf.reduce_mean(dot_product)

# %%
def combine_l2_cosine_loss(y_pred, y_true, lamda=0.2):
    return l2_loss(y_pred, y_true) + lamda*cosine_loss(y_pred, y_true)

# %% [markdown]
# # Train & Evaluation

# %%
""" start training """
loss_function = combine_l2_cosine_loss

max_epochs = 1000
batch_size = 32


loss_history = []
val_loss_best = np.inf
train_size = int(images.shape[0] * 0.6)

#Early stopping hyperparameter
patience = 50  # number of epochs to wait before stopping if there is no improvement
wait = 0  # counter for epochs without improvement


for epoch in range(max_epochs):
    # get a minibatch
    idx = np.random.permutation(train_size)
    batch_idx = idx[:batch_size]

    # optimize
    train_loss = optimize(train_img[batch_idx], train_lmrk[batch_idx], loss_function)
    train_loss = train_loss.numpy()

    # evaluate on val_set
    y = predict(val_img)
    val_loss = loss_function(y, val_lmrk).numpy()

    # Early stopping check
    if val_loss < val_loss_best:
        val_loss_best = val_loss
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            print(f'Early stopping on epoch {epoch}')
            break
        
    print('Epoch:', epoch, '. Training Loss:', train_loss, ' Validation Loss:', val_loss, ' Best Validation Loss:', val_loss_best)
    loss_history.append([train_loss, val_loss])
# Out:
# Epoch: 0 . Training Loss: 2735.7483  Validation Loss: 1992.8623  Best Validation Loss: 1992.8623
# Epoch: 1 . Training Loss: 1987.4528  Validation Loss: 1489.5195  Best Validation Loss: 1489.5195
# Epoch: 2 . Training Loss: 1497.6193  Validation Loss: 1250.1385  Best Validation Loss: 1250.1385
# Epoch: 3 . Training Loss: 1296.8297  Validation Loss: 1050.575  Best Validation Loss: 1050.575
# Epoch: 4 . Training Loss: 1033.0795  Validation Loss: 902.61707  Best Validation Loss: 902.61707
# Epoch: 5 . Training Loss: 941.8694  Validation Loss: 816.8612  Best Validation Loss: 816.8612
# Epoch: 6 . Training Loss: 829.00854  Validation Loss: 728.7864  Best Validation Loss: 728.7864
# Epoch: 7 . Training Loss: 699.0103  Validation Loss: 632.0795  Best Validation Loss: 632.0795
# Epoch: 8 . Training Loss: 640.29913  Validation Loss: 575.01025  Best Validation Loss: 575.01025
# Epoch: 9 . Training Loss: 573.436  Validation Loss: 517.3705  Best Validation Loss: 517.3705
# Epoch: 10 . Training Loss: 495.40842  Validation Loss: 460.2665  Best Validation Loss: 460.2665
# Epoch: 11 . Training Loss: 434.50876  Validation Loss: 440.8321  Best Validation Loss: 440.8321
# Epoch: 12 . Training Loss: 438.17572  Validation Loss: 416.20972  Best Validation Loss: 416.20972
# Epoch: 13 . Training Loss: 419.29752  Validation Loss: 376.30627  Best Validation Loss: 376.30627
# Epoch: 14 . Training Loss: 340.62735  Validation Loss: 345.65088  Best Validation Loss: 345.65088
# Epoch: 15 . Training Loss: 335.56296  Validation Loss: 324.24213  Best Validation Loss: 324.24213
# Epoch: 16 . Training Loss: 319.6238  Validation Loss: 307.41333  Best Validation Loss: 307.41333
# Epoch: 17 . Training Loss: 338.47565  Validation Loss: 279.5947  Best Validation Loss: 279.5947
# Epoch: 18 . Training Loss: 267.34097  Validation Loss: 258.69437  Best Validation Loss: 258.69437
# Epoch: 19 . Training Loss: 257.08163  Validation Loss: 245.38116  Best Validation Loss: 245.38116
# Epoch: 20 . Training Loss: 227.08708  Validation Loss: 228.64908  Best Validation Loss: 228.64908
# Epoch: 21 . Training Loss: 216.84627  Validation Loss: 209.92316  Best Validation Loss: 209.92316
# Epoch: 22 . Training Loss: 208.89467  Validation Loss: 202.15106  Best Validation Loss: 202.15106
# Epoch: 23 . Training Loss: 191.17175  Validation Loss: 191.79814  Best Validation Loss: 191.79814
# Epoch: 24 . Training Loss: 180.03136  Validation Loss: 182.3214  Best Validation Loss: 182.3214
# Epoch: 25 . Training Loss: 177.50317  Validation Loss: 175.23811  Best Validation Loss: 175.23811
# Epoch: 26 . Training Loss: 186.26326  Validation Loss: 169.05348  Best Validation Loss: 169.05348
# Epoch: 27 . Training Loss: 181.0667  Validation Loss: 170.39398  Best Validation Loss: 169.05348
# Epoch: 28 . Training Loss: 174.53424  Validation Loss: 156.32758  Best Validation Loss: 156.32758
# Epoch: 29 . Training Loss: 169.8516  Validation Loss: 148.3823  Best Validation Loss: 148.3823
# Epoch: 30 . Training Loss: 134.54773  Validation Loss: 152.92664  Best Validation Loss: 148.3823
# Epoch: 31 . Training Loss: 168.94223  Validation Loss: 145.12534  Best Validation Loss: 145.12534
# Epoch: 32 . Training Loss: 136.27223  Validation Loss: 142.4493  Best Validation Loss: 142.4493
# Epoch: 33 . Training Loss: 151.9572  Validation Loss: 138.83806  Best Validation Loss: 138.83806
# Epoch: 34 . Training Loss: 102.56429  Validation Loss: 136.88391  Best Validation Loss: 136.88391
# Epoch: 35 . Training Loss: 121.348625  Validation Loss: 156.61214  Best Validation Loss: 136.88391
# Epoch: 36 . Training Loss: 125.156845  Validation Loss: 156.43636  Best Validation Loss: 136.88391
# Epoch: 37 . Training Loss: 176.9242  Validation Loss: 138.6769  Best Validation Loss: 136.88391
# Epoch: 38 . Training Loss: 163.99927  Validation Loss: 133.46277  Best Validation Loss: 133.46277
# Epoch: 39 . Training Loss: 201.57861  Validation Loss: 134.14772  Best Validation Loss: 133.46277
# Epoch: 40 . Training Loss: 105.796196  Validation Loss: 131.61568  Best Validation Loss: 131.61568
# Epoch: 41 . Training Loss: 109.62804  Validation Loss: 129.56161  Best Validation Loss: 129.56161
# Epoch: 42 . Training Loss: 97.276  Validation Loss: 130.02559  Best Validation Loss: 129.56161
# Epoch: 43 . Training Loss: 160.10307  Validation Loss: 129.00728  Best Validation Loss: 129.00728
# Epoch: 44 . Training Loss: 128.46405  Validation Loss: 128.62413  Best Validation Loss: 128.62413
# Epoch: 45 . Training Loss: 114.712234  Validation Loss: 129.49226  Best Validation Loss: 128.62413
# Epoch: 46 . Training Loss: 154.2332  Validation Loss: 127.58691  Best Validation Loss: 127.58691
# Epoch: 47 . Training Loss: 156.98218  Validation Loss: 128.57956  Best Validation Loss: 127.58691
# Epoch: 48 . Training Loss: 103.42662  Validation Loss: 133.3187  Best Validation Loss: 127.58691
# Epoch: 49 . Training Loss: 143.3016  Validation Loss: 125.99989  Best Validation Loss: 125.99989
# Epoch: 50 . Training Loss: 98.18437  Validation Loss: 125.61555  Best Validation Loss: 125.61555
# Epoch: 51 . Training Loss: 115.804054  Validation Loss: 129.42636  Best Validation Loss: 125.61555
# Epoch: 52 . Training Loss: 115.38014  Validation Loss: 126.442184  Best Validation Loss: 125.61555
# Epoch: 53 . Training Loss: 120.47989  Validation Loss: 123.80194  Best Validation Loss: 123.80194
# Epoch: 54 . Training Loss: 101.37673  Validation Loss: 128.0534  Best Validation Loss: 123.80194
# Epoch: 55 . Training Loss: 119.880974  Validation Loss: 126.674576  Best Validation Loss: 123.80194
# Epoch: 56 . Training Loss: 143.4388  Validation Loss: 161.56506  Best Validation Loss: 123.80194
# Epoch: 57 . Training Loss: 190.5493  Validation Loss: 145.36838  Best Validation Loss: 123.80194
# Epoch: 58 . Training Loss: 160.61716  Validation Loss: 121.25218  Best Validation Loss: 121.25218
# Epoch: 59 . Training Loss: 116.07733  Validation Loss: 126.259384  Best Validation Loss: 121.25218
# Epoch: 60 . Training Loss: 99.20613  Validation Loss: 123.240685  Best Validation Loss: 121.25218
# Epoch: 61 . Training Loss: 142.8549  Validation Loss: 127.57161  Best Validation Loss: 121.25218
# Epoch: 62 . Training Loss: 192.24702  Validation Loss: 131.9013  Best Validation Loss: 121.25218
# Epoch: 63 . Training Loss: 141.59889  Validation Loss: 119.7222  Best Validation Loss: 119.7222
# Epoch: 64 . Training Loss: 93.41017  Validation Loss: 127.92821  Best Validation Loss: 119.7222
# Epoch: 65 . Training Loss: 128.06064  Validation Loss: 124.95826  Best Validation Loss: 119.7222
# Epoch: 66 . Training Loss: 97.699425  Validation Loss: 118.89782  Best Validation Loss: 118.89782
# Epoch: 67 . Training Loss: 125.554474  Validation Loss: 118.94098  Best Validation Loss: 118.89782
# Epoch: 68 . Training Loss: 97.15195  Validation Loss: 118.07637  Best Validation Loss: 118.07637
# Epoch: 69 . Training Loss: 129.0781  Validation Loss: 117.82938  Best Validation Loss: 117.82938
# Epoch: 70 . Training Loss: 117.65861  Validation Loss: 117.27356  Best Validation Loss: 117.27356
# Epoch: 71 . Training Loss: 131.6052  Validation Loss: 119.27712  Best Validation Loss: 117.27356
# Epoch: 72 . Training Loss: 115.292366  Validation Loss: 116.499886  Best Validation Loss: 116.499886
# Epoch: 73 . Training Loss: 111.75718  Validation Loss: 118.78971  Best Validation Loss: 116.499886
# Epoch: 74 . Training Loss: 82.88084  Validation Loss: 118.568245  Best Validation Loss: 116.499886
# Epoch: 75 . Training Loss: 138.87054  Validation Loss: 115.16776  Best Validation Loss: 115.16776
# Epoch: 76 . Training Loss: 102.233406  Validation Loss: 115.91752  Best Validation Loss: 115.16776
# Epoch: 77 . Training Loss: 137.38817  Validation Loss: 114.4578  Best Validation Loss: 114.4578
# Epoch: 78 . Training Loss: 94.32275  Validation Loss: 114.12601  Best Validation Loss: 114.12601
# Epoch: 79 . Training Loss: 94.828865  Validation Loss: 116.20177  Best Validation Loss: 114.12601
# Epoch: 80 . Training Loss: 111.78449  Validation Loss: 116.41506  Best Validation Loss: 114.12601
# Epoch: 81 . Training Loss: 123.97148  Validation Loss: 113.43736  Best Validation Loss: 113.43736
# Epoch: 82 . Training Loss: 89.039635  Validation Loss: 119.15487  Best Validation Loss: 113.43736
# Epoch: 83 . Training Loss: 65.89056  Validation Loss: 125.16016  Best Validation Loss: 113.43736
# Epoch: 84 . Training Loss: 109.88852  Validation Loss: 112.72202  Best Validation Loss: 112.72202
# Epoch: 85 . Training Loss: 102.31988  Validation Loss: 124.74512  Best Validation Loss: 112.72202
# Epoch: 86 . Training Loss: 90.7772  Validation Loss: 112.91279  Best Validation Loss: 112.72202
# Epoch: 87 . Training Loss: 115.176926  Validation Loss: 119.009346  Best Validation Loss: 112.72202
# Epoch: 88 . Training Loss: 129.64433  Validation Loss: 143.61209  Best Validation Loss: 112.72202
# Epoch: 89 . Training Loss: 127.89835  Validation Loss: 114.46216  Best Validation Loss: 112.72202
# Epoch: 90 . Training Loss: 70.052475  Validation Loss: 123.93299  Best Validation Loss: 112.72202
# Epoch: 91 . Training Loss: 117.46792  Validation Loss: 188.45973  Best Validation Loss: 112.72202
# Epoch: 92 . Training Loss: 188.18968  Validation Loss: 110.54749  Best Validation Loss: 110.54749
# Epoch: 93 . Training Loss: 138.77438  Validation Loss: 145.93298  Best Validation Loss: 110.54749
# Epoch: 94 . Training Loss: 142.9044  Validation Loss: 145.54019  Best Validation Loss: 110.54749
# Epoch: 95 . Training Loss: 96.96795  Validation Loss: 116.047966  Best Validation Loss: 110.54749
# Epoch: 96 . Training Loss: 106.4069  Validation Loss: 121.237816  Best Validation Loss: 110.54749
# Epoch: 97 . Training Loss: 83.49881  Validation Loss: 170.19327  Best Validation Loss: 110.54749
# Epoch: 98 . Training Loss: 165.38277  Validation Loss: 122.738434  Best Validation Loss: 110.54749
# Epoch: 99 . Training Loss: 110.197525  Validation Loss: 129.22028  Best Validation Loss: 110.54749
# Epoch: 100 . Training Loss: 146.17348  Validation Loss: 159.96996  Best Validation Loss: 110.54749
# Epoch: 101 . Training Loss: 183.27818  Validation Loss: 125.123055  Best Validation Loss: 110.54749
# Early stopping on epoch 102

# %% [markdown]
# ### visualization loss

# %%
# Convert the history to a pandas dataframe
df_loss_history = pd.DataFrame(loss_history, columns=['train_loss', 'val_loss'])

# plot train and validation loss
plt.figure(figsize=(10, 6))
plt.plot(df_loss_history['train_loss'], label='Train Loss')
plt.plot(df_loss_history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train vs Validation Loss over time')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation

# %%
test_true = test_lmrk
test_pred = model.predict(test_img)

print("Combine L2 And Cosine Error: ", combine_l2_cosine_loss(test_true, test_pred).numpy())
# Out:
# Combine L2 And Cosine Error:  107.821655

# %% [markdown]
# ### visualize result

# %%
def plot_sample(image, landmarks, ax):
    ax.imshow(image, cmap='gray')
    landmarks = np.reshape(landmarks, (-1, 2)) # reshape to (15, 2)
    ax.scatter(landmarks[:, 0], landmarks[:, 1], marker='o', s=10)

# suppose we have some predictions and ground truth data
predictions = model.predict(test_img)
ground_truth = test_lmrk  # assume this exists

errors = np.mean(np.abs(predictions - ground_truth), axis=1)
sorted_indices = np.argsort(errors)

# Indices of good predictions
good_indices = sorted_indices[:5]  

# Indices of bad predictions
bad_indices = sorted_indices[-5:]  

fig = plt.figure(figsize=(20,10))
for i in range(5):
    # Good predictions
    ax = fig.add_subplot(2, 5, i+1)
    plot_sample(test_img[good_indices[i]], predictions[good_indices[i]], ax)
    ax.set_title("Good prediction \nCombine L2 And Cosine Error: {:.2f}".format(errors[good_indices[i]]))

    # Bad predictions
    ax = fig.add_subplot(2, 5, i+6)
    plot_sample(test_img[bad_indices[i]], predictions[bad_indices[i]], ax)
    ax.set_title("Bad prediction \nCombine L2 And Cosine Error: {:.2f}".format(errors[bad_indices[i]]))

plt.show()
