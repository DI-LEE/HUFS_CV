# %%
import tensorflow as tf
import scipy.io as io
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Load Data

# %%
def loadData():
    data = io.loadmat("face_landmark.mat")
    images = data["images"]
    landmarks = data["landmarks"]
    print("im_shape:", images.shape)
    print("landmarks_shape:", landmarks.shape)

    return images, landmarks

# %%
images, landmarks = loadData()
# Out:
# im_shape: (2140, 96, 96)
# landmarks_shape: (2140, 15, 2)

# %% [markdown]
# # Visualize Data

# %%
def visualize_data(images, landmarks, num_images):
    fig = plt.figure(figsize=(10,10))
    fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

    for i in range(num_images):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        ax.imshow(images[i], cmap='gray')
        for (x, y) in landmarks[i].reshape(-1, 2):
            # Plot keypoints/landmarks on the image
            ax.scatter(x, y, marker='o', s=10, color='r')

    plt.show()

# %%
visualize_data(images, landmarks, num_images=16)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### split

# %%
def split_data(data, size):
    np.random.seed(2023)
    
    idx = np.random.permutation(size)

    train_size = int(size * 0.6)
    val_size = int(size * 0.2)
    test_size = int(size * 0.2)

    train_ds = data[idx[: train_size]]
    val_ds = data[idx[train_size: train_size + val_size]]
    test_ds = data[idx[size - test_size:]]

    return train_ds, val_ds, test_ds

# %%
train_img, val_img, test_img = split_data(images, images.shape[0])

# %%
train_lmrk, val_lmrk, test_lmrk = split_data(landmarks, landmarks.shape[0])

# %% [markdown]
# ### Reshape

# %%
print(train_img.shape)
print(train_lmrk.shape)
# Out:
# (1284, 96, 96)
# (1284, 15, 2)

# %%
print(val_img.shape)
print(val_lmrk.shape)
# Out:
# (428, 96, 96)
# (428, 15, 2)

# %%
print(test_img.shape)
print(test_lmrk.shape)
# Out:
# (428, 96, 96)
# (428, 15, 2)

# %%
train_lmrk = train_lmrk.reshape((1284, -1))
val_lmrk = val_lmrk.reshape((428, -1))
test_lmrk = test_lmrk.reshape((428, -1))

# %%
print(train_lmrk.shape)
print(val_lmrk.shape)
print(test_lmrk.shape)
# Out:
# (1284, 30)
# (428, 30)
# (428, 30)

# %% [markdown]
# # Model
# * Output은 15개의 얼굴 랜드마크에 해당하는 x, y 좌표이므로 총 30개의 출력 유닛이 필요

# %%
# Define the input shape
input_layer = tf.keras.Input(shape=(96, 96, 1))

# Define the convolution and pooling layers
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(input_layer)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)

# Flatten the tensor output for the Fully Connected layer
x = tf.keras.layers.Flatten()(x)

# Define the fully connected layer
x = tf.keras.layers.Dense(64, activation='relu')(x)

# Define the output layer (30 units for 15 landmarks x and y coordinates)
output_layer = tf.keras.layers.Dense(30)(x)

# Create the model
model = tf.keras.Model(input_layer, output_layer)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 96, 96, 1)]       0
#
#  conv2d (Conv2D)             (None, 94, 94, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 47, 47, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 45, 45, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 22, 22, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 64)                65600
#
#  dense_1 (Dense)             (None, 30)                1950
#
# =================================================================
# Total params: 132,542
# Trainable params: 132,542
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Predict

# %%
@tf.function
def predict(x):
    return model(x, training=False)

# %% [markdown]
# # Optimization

# %%
@tf.function
def optimize(x,y_true,loss_function):
    with tf.GradientTape() as tape:
        y_pred = predict(x)
        loss = loss_function(y_pred, y_true)
    grads = tape.gradient(loss, model.trainable_variables)
    opt.apply_gradients(zip(grads, model.trainable_variables))
    return loss

# %%
opt = tf.keras.optimizers.Adam(learning_rate=1e-3)

# %% [markdown]
# # Loss
# * 실제 레이블(y_true)와 모델의 예측 결과(y)를 입력

# %%
@tf.function
def l1_loss(y_pred, y_true):
    return tf.reduce_mean(tf.abs(y_true - y_pred))

@tf.function
def l2_loss(y_pred, y_true):
    return tf.reduce_mean(tf.square(y_true - y_pred))

@tf.function
def cosine_loss(y_pred, y_true):
    # Normalize each vector
    y_true_normalized = tf.nn.l2_normalize(y_true, axis=-1)
    y_pred_normalized = tf.nn.l2_normalize(y_pred, axis=-1)
    # Compute the dot product (cosine similarity)
    dot_product = tf.reduce_sum(y_true_normalized * y_pred_normalized, axis=-1)
    # Subtract the dot product from 1 to get the loss
    return 1 - tf.reduce_mean(dot_product)

# %%
def combine_l2_cosine_loss(y_pred, y_true, lamda=1.4):
    return l2_loss(y_pred, y_true) + lamda*cosine_loss(y_pred, y_true)

# %% [markdown]
# # Train & Evaluation

# %%
""" start training """
loss_function = combine_l2_cosine_loss

max_epochs = 1000
batch_size = 32


loss_history = []
val_loss_best = np.inf
train_size = int(images.shape[0] * 0.6)

#Early stopping hyperparameter
patience = 50  # number of epochs to wait before stopping if there is no improvement
wait = 0  # counter for epochs without improvement


for epoch in range(max_epochs):
    # get a minibatch
    idx = np.random.permutation(train_size)
    batch_idx = idx[:batch_size]

    # optimize
    train_loss = optimize(train_img[batch_idx], train_lmrk[batch_idx], loss_function)
    train_loss = train_loss.numpy()

    # evaluate on val_set
    y = predict(val_img)
    val_loss = loss_function(y, val_lmrk).numpy()

    # Early stopping check
    if val_loss < val_loss_best:
        val_loss_best = val_loss
        wait = 0
    else:
        wait += 1
        if wait >= patience:
            print(f'Early stopping on epoch {epoch}')
            break
        
    print('Epoch:', epoch, '. Training Loss:', train_loss, ' Validation Loss:', val_loss, ' Best Validation Loss:', val_loss_best)
    loss_history.append([train_loss, val_loss])
# Out:
# Epoch: 0 . Training Loss: 2622.1177  Validation Loss: 2292.5754  Best Validation Loss: 2292.5754
# Epoch: 1 . Training Loss: 2284.2913  Validation Loss: 2039.7667  Best Validation Loss: 2039.7667
# Epoch: 2 . Training Loss: 2043.9604  Validation Loss: 1763.2874  Best Validation Loss: 1763.2874
# Epoch: 3 . Training Loss: 1762.213  Validation Loss: 1526.965  Best Validation Loss: 1526.965
# Epoch: 4 . Training Loss: 1508.8302  Validation Loss: 1389.3862  Best Validation Loss: 1389.3862
# Epoch: 5 . Training Loss: 1431.2035  Validation Loss: 1240.7582  Best Validation Loss: 1240.7582
# Epoch: 6 . Training Loss: 1248.3275  Validation Loss: 1083.8354  Best Validation Loss: 1083.8354
# Epoch: 7 . Training Loss: 1055.6173  Validation Loss: 929.82495  Best Validation Loss: 929.82495
# Epoch: 8 . Training Loss: 939.32904  Validation Loss: 791.65533  Best Validation Loss: 791.65533
# Epoch: 9 . Training Loss: 770.89825  Validation Loss: 662.0627  Best Validation Loss: 662.0627
# Epoch: 10 . Training Loss: 628.46344  Validation Loss: 555.2977  Best Validation Loss: 555.2977
# Epoch: 11 . Training Loss: 514.4895  Validation Loss: 467.18402  Best Validation Loss: 467.18402
# Epoch: 12 . Training Loss: 459.01895  Validation Loss: 399.10986  Best Validation Loss: 399.10986
# Epoch: 13 . Training Loss: 413.22595  Validation Loss: 354.19254  Best Validation Loss: 354.19254
# Epoch: 14 . Training Loss: 337.78925  Validation Loss: 306.22168  Best Validation Loss: 306.22168
# Epoch: 15 . Training Loss: 288.84967  Validation Loss: 265.21567  Best Validation Loss: 265.21567
# Epoch: 16 . Training Loss: 268.37787  Validation Loss: 234.08641  Best Validation Loss: 234.08641
# Epoch: 17 . Training Loss: 272.5002  Validation Loss: 217.48645  Best Validation Loss: 217.48645
# Epoch: 18 . Training Loss: 204.66608  Validation Loss: 202.10283  Best Validation Loss: 202.10283
# Epoch: 19 . Training Loss: 198.4807  Validation Loss: 198.68643  Best Validation Loss: 198.68643
# Epoch: 20 . Training Loss: 173.15219  Validation Loss: 194.35881  Best Validation Loss: 194.35881
# Epoch: 21 . Training Loss: 179.69678  Validation Loss: 184.2487  Best Validation Loss: 184.2487
# Epoch: 22 . Training Loss: 179.35924  Validation Loss: 175.9658  Best Validation Loss: 175.9658
# Epoch: 23 . Training Loss: 161.68141  Validation Loss: 170.18909  Best Validation Loss: 170.18909
# Epoch: 24 . Training Loss: 166.27884  Validation Loss: 164.42955  Best Validation Loss: 164.42955
# Epoch: 25 . Training Loss: 160.04274  Validation Loss: 164.0833  Best Validation Loss: 164.0833
# Epoch: 26 . Training Loss: 189.58278  Validation Loss: 153.4387  Best Validation Loss: 153.4387
# Epoch: 27 . Training Loss: 168.33774  Validation Loss: 167.53993  Best Validation Loss: 153.4387
# Epoch: 28 . Training Loss: 173.64272  Validation Loss: 156.9455  Best Validation Loss: 153.4387
# Epoch: 29 . Training Loss: 163.71635  Validation Loss: 146.05913  Best Validation Loss: 146.05913
# Epoch: 30 . Training Loss: 131.24574  Validation Loss: 156.45181  Best Validation Loss: 146.05913
# Epoch: 31 . Training Loss: 170.53563  Validation Loss: 148.52342  Best Validation Loss: 146.05913
# Epoch: 32 . Training Loss: 129.98863  Validation Loss: 144.67429  Best Validation Loss: 144.67429
# Epoch: 33 . Training Loss: 151.1618  Validation Loss: 141.81876  Best Validation Loss: 141.81876
# Epoch: 34 . Training Loss: 105.64346  Validation Loss: 143.0691  Best Validation Loss: 141.81876
# Epoch: 35 . Training Loss: 126.643005  Validation Loss: 166.26497  Best Validation Loss: 141.81876
# Epoch: 36 . Training Loss: 133.87717  Validation Loss: 162.38773  Best Validation Loss: 141.81876
# Epoch: 37 . Training Loss: 186.2493  Validation Loss: 144.0661  Best Validation Loss: 141.81876
# Epoch: 38 . Training Loss: 163.46684  Validation Loss: 146.20903  Best Validation Loss: 141.81876
# Epoch: 39 . Training Loss: 218.31033  Validation Loss: 141.12152  Best Validation Loss: 141.12152
# Epoch: 40 . Training Loss: 116.81348  Validation Loss: 136.9245  Best Validation Loss: 136.9245
# Epoch: 41 . Training Loss: 119.2786  Validation Loss: 135.3373  Best Validation Loss: 135.3373
# Epoch: 42 . Training Loss: 102.88208  Validation Loss: 133.4819  Best Validation Loss: 133.4819
# Epoch: 43 . Training Loss: 158.71286  Validation Loss: 133.7274  Best Validation Loss: 133.4819
# Epoch: 44 . Training Loss: 134.61612  Validation Loss: 130.36334  Best Validation Loss: 130.36334
# Epoch: 45 . Training Loss: 117.56049  Validation Loss: 132.05183  Best Validation Loss: 130.36334
# Epoch: 46 . Training Loss: 159.97023  Validation Loss: 130.71335  Best Validation Loss: 130.36334
# Epoch: 47 . Training Loss: 159.35854  Validation Loss: 131.57906  Best Validation Loss: 130.36334
# Epoch: 48 . Training Loss: 102.902306  Validation Loss: 132.76363  Best Validation Loss: 130.36334
# Epoch: 49 . Training Loss: 138.5328  Validation Loss: 127.02836  Best Validation Loss: 127.02836
# Epoch: 50 . Training Loss: 107.21857  Validation Loss: 124.65089  Best Validation Loss: 124.65089
# Epoch: 51 . Training Loss: 117.3176  Validation Loss: 131.50009  Best Validation Loss: 124.65089
# Epoch: 52 . Training Loss: 116.03572  Validation Loss: 127.69986  Best Validation Loss: 124.65089
# Epoch: 53 . Training Loss: 121.60775  Validation Loss: 122.47983  Best Validation Loss: 122.47983
# Epoch: 54 . Training Loss: 101.51548  Validation Loss: 129.00525  Best Validation Loss: 122.47983
# Epoch: 55 . Training Loss: 126.96092  Validation Loss: 123.9342  Best Validation Loss: 122.47983
# Epoch: 56 . Training Loss: 148.2012  Validation Loss: 160.62392  Best Validation Loss: 122.47983
# Epoch: 57 . Training Loss: 193.66791  Validation Loss: 151.75365  Best Validation Loss: 122.47983
# Epoch: 58 . Training Loss: 170.68439  Validation Loss: 124.429146  Best Validation Loss: 122.47983
# Epoch: 59 . Training Loss: 117.98599  Validation Loss: 121.716805  Best Validation Loss: 121.716805
# Epoch: 60 . Training Loss: 89.20411  Validation Loss: 126.54928  Best Validation Loss: 121.716805
# Epoch: 61 . Training Loss: 152.69243  Validation Loss: 119.99973  Best Validation Loss: 119.99973
# Epoch: 62 . Training Loss: 181.40947  Validation Loss: 122.3512  Best Validation Loss: 119.99973
# Epoch: 63 . Training Loss: 128.35559  Validation Loss: 119.043526  Best Validation Loss: 119.043526
# Epoch: 64 . Training Loss: 91.13502  Validation Loss: 120.760956  Best Validation Loss: 119.043526
# Epoch: 65 . Training Loss: 120.498375  Validation Loss: 119.10604  Best Validation Loss: 119.043526
# Epoch: 66 . Training Loss: 90.03027  Validation Loss: 118.69662  Best Validation Loss: 118.69662
# Epoch: 67 . Training Loss: 121.87009  Validation Loss: 117.86604  Best Validation Loss: 117.86604
# Epoch: 68 . Training Loss: 91.28879  Validation Loss: 120.964386  Best Validation Loss: 117.86604
# Epoch: 69 . Training Loss: 141.0463  Validation Loss: 116.61708  Best Validation Loss: 116.61708
# Epoch: 70 . Training Loss: 118.140686  Validation Loss: 118.42266  Best Validation Loss: 116.61708
# Epoch: 71 . Training Loss: 128.73108  Validation Loss: 123.35661  Best Validation Loss: 116.61708
# Epoch: 72 . Training Loss: 123.00497  Validation Loss: 115.556145  Best Validation Loss: 115.556145
# Epoch: 73 . Training Loss: 106.09198  Validation Loss: 123.3828  Best Validation Loss: 115.556145
# Epoch: 74 . Training Loss: 92.46728  Validation Loss: 120.73596  Best Validation Loss: 115.556145
# Epoch: 75 . Training Loss: 141.44911  Validation Loss: 114.507614  Best Validation Loss: 114.507614
# Epoch: 76 . Training Loss: 106.49442  Validation Loss: 118.94251  Best Validation Loss: 114.507614
# Epoch: 77 . Training Loss: 141.39667  Validation Loss: 115.808205  Best Validation Loss: 114.507614
# Epoch: 78 . Training Loss: 89.570786  Validation Loss: 113.23819  Best Validation Loss: 113.23819
# Epoch: 79 . Training Loss: 91.769554  Validation Loss: 118.67143  Best Validation Loss: 113.23819
# Epoch: 80 . Training Loss: 115.27043  Validation Loss: 120.86164  Best Validation Loss: 113.23819
# Epoch: 81 . Training Loss: 130.83134  Validation Loss: 111.60155  Best Validation Loss: 111.60155
# Epoch: 82 . Training Loss: 93.123055  Validation Loss: 120.73864  Best Validation Loss: 111.60155
# Epoch: 83 . Training Loss: 66.88545  Validation Loss: 134.16084  Best Validation Loss: 111.60155
# Epoch: 84 . Training Loss: 125.37082  Validation Loss: 120.38268  Best Validation Loss: 111.60155
# Epoch: 85 . Training Loss: 110.85356  Validation Loss: 112.30674  Best Validation Loss: 111.60155
# Epoch: 86 . Training Loss: 85.145195  Validation Loss: 133.82759  Best Validation Loss: 111.60155
# Epoch: 87 . Training Loss: 140.35587  Validation Loss: 110.30984  Best Validation Loss: 110.30984
# Epoch: 88 . Training Loss: 138.41579  Validation Loss: 143.25076  Best Validation Loss: 110.30984
# Epoch: 89 . Training Loss: 128.35278  Validation Loss: 151.08224  Best Validation Loss: 110.30984
# Epoch: 90 . Training Loss: 108.56713  Validation Loss: 116.422775  Best Validation Loss: 110.30984
# Epoch: 91 . Training Loss: 148.48987  Validation Loss: 136.69374  Best Validation Loss: 110.30984
# Epoch: 92 . Training Loss: 142.56119  Validation Loss: 168.82683  Best Validation Loss: 110.30984
# Epoch: 93 . Training Loss: 199.54851  Validation Loss: 112.31797  Best Validation Loss: 110.30984
# Epoch: 94 . Training Loss: 85.240845  Validation Loss: 117.30256  Best Validation Loss: 110.30984
# Epoch: 95 . Training Loss: 80.008255  Validation Loss: 151.25687  Best Validation Loss: 110.30984
# Epoch: 96 . Training Loss: 141.98515  Validation Loss: 139.76178  Best Validation Loss: 110.30984
# Epoch: 97 . Training Loss: 132.10616  Validation Loss: 108.66166  Best Validation Loss: 108.66166
# Epoch: 98 . Training Loss: 115.05801  Validation Loss: 140.31406  Best Validation Loss: 108.66166
# Epoch: 99 . Training Loss: 136.06955  Validation Loss: 127.83637  Best Validation Loss: 108.66166
# Epoch: 100 . Training Loss: 111.27491  Validation Loss: 110.33363  Best Validation Loss: 108.66166
# Epoch: 101 . Training Loss: 95.0041  Validation Loss: 107.83516  Best Validation Loss: 107.83516
# Epoch: 102 . Training Loss: 101.92768  Validation Loss: 112.6598  Best Validation Loss: 107.83516
# Epoch: 103 . Training Loss: 93.766266  Validation Loss: 118.17958  Best Validation Loss: 107.83516
# Epoch: 104 . Training Loss: 81.31085  Validation Loss: 113.39342  Best Validation Loss: 107.83516
# Epoch: 105 . Training Loss: 108.20784  Validation Loss: 107.67062  Best Validation Loss: 107.67062
# Epoch: 106 . Training Loss: 107.37114  Validation Loss: 117.81218  Best Validation Loss: 107.67062
# Epoch: 107 . Training Loss: 104.27526  Validation Loss: 120.743256  Best Validation Loss: 107.67062
# Epoch: 108 . Training Loss: 119.80659  Validation Loss: 106.96346  Best Validation Loss: 106.96346
# Epoch: 109 . Training Loss: 123.82225  Validation Loss: 110.76459  Best Validation Loss: 106.96346
# Epoch: 110 . Training Loss: 83.22555  Validation Loss: 112.73999  Best Validation Loss: 106.96346
# Epoch: 111 . Training Loss: 135.453  Validation Loss: 107.89128  Best Validation Loss: 106.96346
# Epoch: 112 . Training Loss: 110.68468  Validation Loss: 105.56463  Best Validation Loss: 105.56463
# Epoch: 113 . Training Loss: 86.861015  Validation Loss: 109.16261  Best Validation Loss: 105.56463
# Epoch: 114 . Training Loss: 82.62551  Validation Loss: 112.50015  Best Validation Loss: 105.56463
# Epoch: 115 . Training Loss: 109.22832  Validation Loss: 104.89702  Best Validation Loss: 104.89702
# Epoch: 116 . Training Loss: 65.21475  Validation Loss: 113.20675  Best Validation Loss: 104.89702
# Epoch: 117 . Training Loss: 129.71332  Validation Loss: 121.0035  Best Validation Loss: 104.89702
# Epoch: 118 . Training Loss: 98.56349  Validation Loss: 110.42961  Best Validation Loss: 104.89702
# Epoch: 119 . Training Loss: 115.28196  Validation Loss: 105.5007  Best Validation Loss: 104.89702
# Epoch: 120 . Training Loss: 105.45869  Validation Loss: 111.92959  Best Validation Loss: 104.89702
# Epoch: 121 . Training Loss: 86.556435  Validation Loss: 112.91605  Best Validation Loss: 104.89702
# Epoch: 122 . Training Loss: 149.55363  Validation Loss: 103.522316  Best Validation Loss: 103.522316
# Epoch: 123 . Training Loss: 116.43845  Validation Loss: 103.003044  Best Validation Loss: 103.003044
# Epoch: 124 . Training Loss: 72.96093  Validation Loss: 105.82717  Best Validation Loss: 103.003044
# Epoch: 125 . Training Loss: 92.90162  Validation Loss: 102.945045  Best Validation Loss: 102.945045
# Epoch: 126 . Training Loss: 86.08151  Validation Loss: 107.8027  Best Validation Loss: 102.945045
# Epoch: 127 . Training Loss: 86.16345  Validation Loss: 121.38996  Best Validation Loss: 102.945045
# Epoch: 128 . Training Loss: 93.15358  Validation Loss: 116.14013  Best Validation Loss: 102.945045
# Epoch: 129 . Training Loss: 85.417274  Validation Loss: 101.691826  Best Validation Loss: 101.691826
# Epoch: 130 . Training Loss: 70.572525  Validation Loss: 108.63264  Best Validation Loss: 101.691826
# Epoch: 131 . Training Loss: 131.0865  Validation Loss: 106.83106  Best Validation Loss: 101.691826
# Epoch: 132 . Training Loss: 88.421005  Validation Loss: 101.03255  Best Validation Loss: 101.03255
# Epoch: 133 . Training Loss: 109.83893  Validation Loss: 107.92114  Best Validation Loss: 101.03255
# Epoch: 134 . Training Loss: 123.01712  Validation Loss: 107.04396  Best Validation Loss: 101.03255
# Epoch: 135 . Training Loss: 82.07024  Validation Loss: 106.05238  Best Validation Loss: 101.03255
# Epoch: 136 . Training Loss: 100.58469  Validation Loss: 100.21754  Best Validation Loss: 100.21754
# Epoch: 137 . Training Loss: 124.293  Validation Loss: 103.80679  Best Validation Loss: 100.21754
# Epoch: 138 . Training Loss: 75.92105  Validation Loss: 105.893135  Best Validation Loss: 100.21754
# Epoch: 139 . Training Loss: 73.70565  Validation Loss: 99.51544  Best Validation Loss: 99.51544
# Epoch: 140 . Training Loss: 120.59844  Validation Loss: 101.3161  Best Validation Loss: 99.51544
# Epoch: 141 . Training Loss: 104.77821  Validation Loss: 102.720215  Best Validation Loss: 99.51544
# Epoch: 142 . Training Loss: 123.49921  Validation Loss: 102.36181  Best Validation Loss: 99.51544
# Epoch: 143 . Training Loss: 159.1255  Validation Loss: 105.305046  Best Validation Loss: 99.51544
# Epoch: 144 . Training Loss: 62.701286  Validation Loss: 134.4481  Best Validation Loss: 99.51544
# Epoch: 145 . Training Loss: 155.60818  Validation Loss: 98.13944  Best Validation Loss: 98.13944
# Epoch: 146 . Training Loss: 82.642746  Validation Loss: 122.52009  Best Validation Loss: 98.13944
# Epoch: 147 . Training Loss: 124.00392  Validation Loss: 123.237  Best Validation Loss: 98.13944
# Epoch: 148 . Training Loss: 115.95029  Validation Loss: 99.30529  Best Validation Loss: 98.13944
# Epoch: 149 . Training Loss: 58.16378  Validation Loss: 102.32198  Best Validation Loss: 98.13944
# Epoch: 150 . Training Loss: 110.96597  Validation Loss: 120.34473  Best Validation Loss: 98.13944
# Epoch: 151 . Training Loss: 101.81314  Validation Loss: 100.85901  Best Validation Loss: 98.13944
# Epoch: 152 . Training Loss: 87.74406  Validation Loss: 110.68453  Best Validation Loss: 98.13944
# Epoch: 153 . Training Loss: 117.801315  Validation Loss: 143.64296  Best Validation Loss: 98.13944
# Epoch: 154 . Training Loss: 145.86801  Validation Loss: 134.65108  Best Validation Loss: 98.13944
# Epoch: 155 . Training Loss: 135.6712  Validation Loss: 97.44011  Best Validation Loss: 97.44011
# Epoch: 156 . Training Loss: 74.74061  Validation Loss: 109.006775  Best Validation Loss: 97.44011
# Epoch: 157 . Training Loss: 97.047615  Validation Loss: 115.03799  Best Validation Loss: 97.44011
# Epoch: 158 . Training Loss: 147.74234  Validation Loss: 98.31342  Best Validation Loss: 97.44011
# Epoch: 159 . Training Loss: 82.150276  Validation Loss: 96.55809  Best Validation Loss: 96.55809
# Epoch: 160 . Training Loss: 85.36934  Validation Loss: 97.090256  Best Validation Loss: 96.55809
# Epoch: 161 . Training Loss: 98.35158  Validation Loss: 94.3496  Best Validation Loss: 94.3496
# Epoch: 162 . Training Loss: 75.38946  Validation Loss: 94.25562  Best Validation Loss: 94.25562
# Epoch: 163 . Training Loss: 97.436676  Validation Loss: 93.846466  Best Validation Loss: 93.846466
# Epoch: 164 . Training Loss: 105.79122  Validation Loss: 95.39047  Best Validation Loss: 93.846466
# Epoch: 165 . Training Loss: 81.75297  Validation Loss: 99.512436  Best Validation Loss: 93.846466
# Epoch: 166 . Training Loss: 107.60047  Validation Loss: 103.24565  Best Validation Loss: 93.846466
# Epoch: 167 . Training Loss: 83.33771  Validation Loss: 96.31186  Best Validation Loss: 93.846466
# Epoch: 168 . Training Loss: 90.279434  Validation Loss: 94.524864  Best Validation Loss: 93.846466
# Epoch: 169 . Training Loss: 111.08388  Validation Loss: 96.30909  Best Validation Loss: 93.846466
# Epoch: 170 . Training Loss: 61.5719  Validation Loss: 94.825134  Best Validation Loss: 93.846466
# Epoch: 171 . Training Loss: 74.897705  Validation Loss: 93.18707  Best Validation Loss: 93.18707
# Epoch: 172 . Training Loss: 80.122215  Validation Loss: 93.749504  Best Validation Loss: 93.18707
# Epoch: 173 . Training Loss: 84.23521  Validation Loss: 92.156525  Best Validation Loss: 92.156525
# Epoch: 174 . Training Loss: 67.916016  Validation Loss: 92.398315  Best Validation Loss: 92.156525
# Epoch: 175 . Training Loss: 53.517506  Validation Loss: 92.95467  Best Validation Loss: 92.156525
# Epoch: 176 . Training Loss: 93.05095  Validation Loss: 93.87081  Best Validation Loss: 92.156525
# Epoch: 177 . Training Loss: 91.11532  Validation Loss: 108.65224  Best Validation Loss: 92.156525
# Epoch: 178 . Training Loss: 108.214165  Validation Loss: 94.15186  Best Validation Loss: 92.156525
# Epoch: 179 . Training Loss: 61.415874  Validation Loss: 101.34038  Best Validation Loss: 92.156525
# Epoch: 180 . Training Loss: 74.39248  Validation Loss: 99.63937  Best Validation Loss: 92.156525
# Epoch: 181 . Training Loss: 86.141  Validation Loss: 92.069725  Best Validation Loss: 92.069725
# Epoch: 182 . Training Loss: 89.01906  Validation Loss: 119.830185  Best Validation Loss: 92.069725
# Epoch: 183 . Training Loss: 109.24308  Validation Loss: 112.636826  Best Validation Loss: 92.069725
# Epoch: 184 . Training Loss: 81.25842  Validation Loss: 89.96856  Best Validation Loss: 89.96856
# Epoch: 185 . Training Loss: 68.35087  Validation Loss: 95.81487  Best Validation Loss: 89.96856
# Epoch: 186 . Training Loss: 61.344654  Validation Loss: 104.0184  Best Validation Loss: 89.96856
# Epoch: 187 . Training Loss: 97.35204  Validation Loss: 95.087685  Best Validation Loss: 89.96856
# Epoch: 188 . Training Loss: 98.430115  Validation Loss: 90.65622  Best Validation Loss: 89.96856
# Epoch: 189 . Training Loss: 90.673935  Validation Loss: 91.448944  Best Validation Loss: 89.96856
# Epoch: 190 . Training Loss: 97.68906  Validation Loss: 88.77731  Best Validation Loss: 88.77731
# Epoch: 191 . Training Loss: 67.14453  Validation Loss: 92.840454  Best Validation Loss: 88.77731
# Epoch: 192 . Training Loss: 74.23908  Validation Loss: 98.74888  Best Validation Loss: 88.77731
# Epoch: 193 . Training Loss: 108.60588  Validation Loss: 92.27221  Best Validation Loss: 88.77731
# Epoch: 194 . Training Loss: 64.975464  Validation Loss: 88.963036  Best Validation Loss: 88.77731
# Epoch: 195 . Training Loss: 72.369995  Validation Loss: 103.53486  Best Validation Loss: 88.77731
# Epoch: 196 . Training Loss: 92.22282  Validation Loss: 98.21443  Best Validation Loss: 88.77731
# Epoch: 197 . Training Loss: 138.23401  Validation Loss: 87.59516  Best Validation Loss: 87.59516
# Epoch: 198 . Training Loss: 72.36555  Validation Loss: 102.71796  Best Validation Loss: 87.59516
# Epoch: 199 . Training Loss: 108.550934  Validation Loss: 100.528824  Best Validation Loss: 87.59516
# Epoch: 200 . Training Loss: 106.754  Validation Loss: 86.446266  Best Validation Loss: 86.446266
# Epoch: 201 . Training Loss: 66.967834  Validation Loss: 95.64101  Best Validation Loss: 86.446266
# Epoch: 202 . Training Loss: 93.37345  Validation Loss: 113.772545  Best Validation Loss: 86.446266
# Epoch: 203 . Training Loss: 142.53426  Validation Loss: 86.6825  Best Validation Loss: 86.446266
# Epoch: 204 . Training Loss: 94.87829  Validation Loss: 102.29379  Best Validation Loss: 86.446266
# Epoch: 205 . Training Loss: 85.252815  Validation Loss: 120.16247  Best Validation Loss: 86.446266
# Epoch: 206 . Training Loss: 134.18431  Validation Loss: 107.96611  Best Validation Loss: 86.446266
# Epoch: 207 . Training Loss: 115.95323  Validation Loss: 86.00499  Best Validation Loss: 86.00499
# Epoch: 208 . Training Loss: 67.04553  Validation Loss: 91.148384  Best Validation Loss: 86.00499
# Epoch: 209 . Training Loss: 65.37081  Validation Loss: 105.507996  Best Validation Loss: 86.00499
# Epoch: 210 . Training Loss: 50.72873  Validation Loss: 99.196945  Best Validation Loss: 86.00499
# Epoch: 211 . Training Loss: 106.66491  Validation Loss: 86.833336  Best Validation Loss: 86.00499
# Epoch: 212 . Training Loss: 76.77218  Validation Loss: 104.220764  Best Validation Loss: 86.00499
# Epoch: 213 . Training Loss: 100.90466  Validation Loss: 116.83194  Best Validation Loss: 86.00499
# Epoch: 214 . Training Loss: 125.746544  Validation Loss: 93.68321  Best Validation Loss: 86.00499
# Epoch: 215 . Training Loss: 116.97658  Validation Loss: 96.65637  Best Validation Loss: 86.00499
# Epoch: 216 . Training Loss: 88.726845  Validation Loss: 128.6482  Best Validation Loss: 86.00499
# Early stopping on epoch 217

# %% [markdown]
# ### visualization loss

# %%
# Convert the history to a pandas dataframe
df_loss_history = pd.DataFrame(loss_history, columns=['train_loss', 'val_loss'])

# plot train and validation loss
plt.figure(figsize=(10, 6))
plt.plot(df_loss_history['train_loss'], label='Train Loss')
plt.plot(df_loss_history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train vs Validation Loss over time')
plt.legend()
plt.show()

# %% [markdown]
# ### Evaluation

# %%
test_true = test_lmrk
test_pred = model.predict(test_img)

print("Combine L2 And Cosine Error: ", combine_l2_cosine_loss(test_true, test_pred).numpy())
# Out:
# Combine L2 And Cosine Error:  99.345505

# %% [markdown]
# ### visualize result

# %%
def plot_sample(image, landmarks, ax):
    ax.imshow(image, cmap='gray')
    landmarks = np.reshape(landmarks, (-1, 2)) # reshape to (15, 2)
    ax.scatter(landmarks[:, 0], landmarks[:, 1], marker='o', s=10)

# suppose we have some predictions and ground truth data
predictions = model.predict(test_img)
ground_truth = test_lmrk  # assume this exists

errors = np.mean(np.abs(predictions - ground_truth), axis=1)
sorted_indices = np.argsort(errors)

# Indices of good predictions
good_indices = sorted_indices[:5]  

# Indices of bad predictions
bad_indices = sorted_indices[-5:]  

fig = plt.figure(figsize=(20,10))
for i in range(5):
    # Good predictions
    ax = fig.add_subplot(2, 5, i+1)
    plot_sample(test_img[good_indices[i]], predictions[good_indices[i]], ax)
    ax.set_title("Good prediction \nCombine L2 And Cosine Error: {:.2f}".format(errors[good_indices[i]]))

    # Bad predictions
    ax = fig.add_subplot(2, 5, i+6)
    plot_sample(test_img[bad_indices[i]], predictions[bad_indices[i]], ax)
    ax.set_title("Bad prediction \nCombine L2 And Cosine Error: {:.2f}".format(errors[bad_indices[i]]))

plt.show()
